# %%
import pandas as pd
from matplotlib import pyplot  as plt
import torch
import numpy as np

# %%
baselines_result = pd.DataFrame([
    # bicycle
    {
        "method": "compactGS",
        "dataset": "mip-nerf-360",
        "scene": "bicycle",
        "rate_point": "0",
        "rate": 42.4831,
        "SSIM": 0.6369403004646301,
        "PSNR": 22.64617156982422,
        "LPIPS": 0.36250948905944824
    },{
        "method": "compactGS",
        "dataset": "mip-nerf-360",
        "scene": "bicycle",
        "rate_point": "1",
        "rate": 30.5611,
        "SSIM": 0.6178025007247925,
        "PSNR": 22.287696838378906,
        "LPIPS": 0.3945152163505554
    },{
        "method": "compactGS",
        "dataset": "mip-nerf-360",
        "scene": "bicycle",
        "rate_point": "2",
        "rate": 26.4783,
        "SSIM": 0.5721822381019592,
        "PSNR": 21.497987747192383,
        "LPIPS": 0.4495748281478882
    },
    # bonsai
    {
        "method": "compactGS",
        "dataset": "mip-nerf-360",
        "scene": "bonsai",
        "rate_point": "0",
        "rate": 16.5196,
        "SSIM": 0.9378640651702881,
        "PSNR": 31.965585708618164,
        "LPIPS": 0.1929798424243927
    },{
        "method": "compactGS",
        "dataset": "mip-nerf-360",
        "scene": "bonsai",
        "rate_point": "1",
        "rate": 13.4177,
        "SSIM": 0.9210731983184814,
        "PSNR": 30.717172622680664,
        "LPIPS": 0.2210499495267868
    },{
        "method": "compactGS",
        "dataset": "mip-nerf-360",
        "scene": "bonsai",
        "rate_point": "2",
        "rate": 12.0413,
        "SSIM": 0.877372145652771,
        "PSNR": 27.986495971679688,
        "LPIPS": 0.2910488545894623
    },
    # counter
    {
        "method": "compactGS",
        "dataset": "mip-nerf-360",
        "scene": "counter",
        "rate_point": "0",
        "rate": 15.4835,
        "SSIM": 0.9017871022224426,
        "PSNR": 28.61504364013672,
        "LPIPS": 0.20520257949829102
    },{
        "method": "compactGS",
        "dataset": "mip-nerf-360",
        "scene": "counter",
        "rate_point": "1",
        "rate": 12.5701,
        "SSIM": 0.8834015130996704,
        "PSNR": 27.896955490112305,
        "LPIPS": 0.23432303965091705
    },{
        "method": "compactGS",
        "dataset": "mip-nerf-360",
        "scene": "counter",
        "rate_point": "2",
        "rate": 11.5985,
        "SSIM": 0.8360680341720581,
        "PSNR": 26.30500030517578,
        "LPIPS": 0.30615413188934326
    },
    # flowers
    {
        "method": "compactGS",
        "dataset": "mip-nerf-360",
        "scene": "flowers",
        "rate_point": "0",
        "rate": 31.8846,
        "SSIM": 0.5544968247413635,
        "PSNR": 20.906023025512695,
        "LPIPS": 0.3993189036846161
    },{
        "method": "compactGS",
        "dataset": "mip-nerf-360",
        "scene": "flowers",
        "rate_point": "1",
        "rate": 23.0635,
        "SSIM": 0.5253291130065918,
        "PSNR": 20.451236724853516,
        "LPIPS": 0.42336785793304443
    },{
        "method": "compactGS",
        "dataset": "mip-nerf-360",
        "scene": "flowers",
        "rate_point": "2",
        "rate": 20.5717,
        "SSIM": 0.4639681875705719,
        "PSNR": 19.557415008544922,
        "LPIPS": 0.47836264967918396
    },
    # garden
    {
        "method": "compactGS",
        "dataset": "mip-nerf-360",
        "scene": "garden",
        "rate_point": "0",
        "rate": 43.1709,
        "SSIM": 0.8318660855293274,
        "PSNR": 26.755022048950195,
        "LPIPS": 0.1590110808610916
    },{
        "method": "compactGS",
        "dataset": "mip-nerf-360",
        "scene": "garden",
        "rate_point": "1",
        "rate": 30.8571,
        "SSIM": 0.8133693337440491,
        "PSNR": 26.326303482055664,
        "LPIPS": 0.18475878238677979
    },{
        "method": "compactGS",
        "dataset": "mip-nerf-360",
        "scene": "garden",
        "rate_point": "2",
        "rate": 26.3121,
        "SSIM": 0.7604450583457947,
        "PSNR": 25.201608657836914,
        "LPIPS": 0.25617077946662903
    },
    # kitchen
    {
        "method": "compactGS",
        "dataset": "mip-nerf-360",
        "scene": "kitchen",
        "rate_point": "0",
        "rate": 24.5489,
        "SSIM": 0.9212367534637451,
        "PSNR": 30.63324546813965,
        "LPIPS": 0.12941591441631317
    },{
        "method": "compactGS",
        "dataset": "mip-nerf-360",
        "scene": "kitchen",
        "rate_point": "1",
        "rate": 18.5672,
        "SSIM": 0.9068609476089478,
        "PSNR": 29.75311851501465,
        "LPIPS": 0.14827463030815125
    },{
        "method": "compactGS",
        "dataset": "mip-nerf-360",
        "scene": "kitchen",
        "rate_point": "2",
        "rate": 16.6061,
        "SSIM": 0.8717551231384277,
        "PSNR": 28.05325698852539,
        "LPIPS": 0.19959507882595062
    },
    # room
    {
        "method": "compactGS",
        "dataset": "mip-nerf-360",
        "scene":

    },{
        "method": "HAC",
        "dataset": "mip-nerf-360",
        "scene": "treehill",
        "rate_point": "2",
        "rate": 23392/1024,
        "SSIM": 0.6453,
        "PSNR": 23.2473,
        "LPIPS": 0.3541,
    },{
        "method": "HAC",
        "dataset": "mip-nerf-360",
        "scene": "treehill",
        "rate_point": "3",
        "rate": 19676/1024,
        "SSIM": 0.6440,
        "PSNR": 23.2909,
        "LPIPS": 0.3583,
    },
    # Origin3DGS - bicycle
    {
        "method": "Origin3DGS",
        "dataset": "mip-nerf-360",
        "scene": "bicycle",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.7476,
        "PSNR": 25.1179,
        "LPIPS": 0.2410,
    },
    # Origin3DGS - bonsai
    {
        "method": "Origin3DGS",
        "dataset": "mip-nerf-360",
        "scene": "bonsai",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.9467,
        "PSNR": 32.4679,
        "LPIPS": 0.1805,
    },
    # Origin3DGS - counter
    {
        "method": "Origin3DGS",
        "dataset": "mip-nerf-360",
        "scene": "counter",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.9158,
        "PSNR": 29.1865,
        "LPIPS": 0.1822,
    },
    # Origin3DGS - flowers
    {
        "method": "Origin3DGS",
        "dataset": "mip-nerf-360",
        "scene": "flowers",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.5879,
        "PSNR": 21.3841,
        "LPIPS": 0.3585,
    },
    # Origin3DGS - garden
    {
        "method": "Origin3DGS",
        "dataset": "mip-nerf-360",
        "scene": "garden",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.8578,
        "PSNR": 27.4207,
        "LPIPS": 0.1214,
    },
    # Origin3DGS - kitchen
    {
        "method": "Origin3DGS",
        "dataset": "mip-nerf-360",
        "scene": "kitchen",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.9316,
        "PSNR": 31.1976,
        "LPIPS": 0.1165,
    },
    # Origin3DGS - room
    {
        "method": "Origin3DGS",
        "dataset": "mip-nerf-360",
        "scene": "room",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.9274,
        "PSNR": 31.8348,
        "LPIPS": 0.1954,
    },
    # Origin3DGS - stump
    {
        "method": "Origin3DGS",
        "dataset": "mip-nerf-360",
        "scene": "stump",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.7686,
        "PSNR": 26.6611,
        "LPIPS": 0.2429,
    },
    # Origin3DGS - treehill
    {
        "method": "Origin3DGS",
        "dataset": "mip-nerf-360",
        "scene": "treehill",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.6359,
        "PSNR": 22.5564,
        "LPIPS": 0.3457,
    },
    # SVRaster - bicycle
    {
        "method": "SVRaster",
        "dataset": "mip-nerf-360",
        "scene": "bicycle",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.7582,
        "PSNR": 25.2219,
        "LPIPS": 0.2123,
    },
    # SVRaster - bonsai
    {
        "method": "SVRaster",
        "dataset": "mip-nerf-360",
        "scene": "bonsai",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.9498,
        "PSNR": 31.6901,
        "LPIPS": 0.1462,
    },
    # SVRaster - counter
    {
        "method": "SVRaster",
        "dataset": "mip-nerf-360",
        "scene": "counter",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.9121,
        "PSNR": 28.8538,
        "LPIPS": 0.1595,
    },
    # SVRaster - flowers
    {
        "method": "SVRaster",
        "dataset": "mip-nerf-360",
        "scene": "flowers",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.6217,
        "PSNR": 21.6278,
        "LPIPS": 0.2912,
    },
    # SVRaster - garden
    {
        "method": "SVRaster",
        "dataset": "mip-nerf-360",
        "scene": "garden",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.8564,
        "PSNR": 27.2622,
        "LPIPS": 0.1173,
    },
    # SVRaster - kitchen
    {
        "method": "SVRaster",
        "dataset": "mip-nerf-360",
        "scene": "kitchen",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.9385,
        "PSNR": 31.5151,
        "LPIPS": 0.1018,
    },
    # SVRaster - room
    {
        "method": "SVRaster",
        "dataset": "mip-nerf-360",
        "scene": "room",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.9319,
        "PSNR": 31.3034,
        "LPIPS": 0.1627,
    },
    # SVRaster - stump
    {
        "method": "SVRaster",
        "dataset": "mip-nerf-360",
        "scene": "stump",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.7613,
        "PSNR": 26.3847,
        "LPIPS": 0.2264,
    },
    # SVRaster - treehill
    {
        "method": "SVRaster",
        "dataset": "mip-nerf-360",
        "scene": "treehill",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.6432,
        "PSNR": 22.7337,
        "LPIPS": 0.2807,
    },
    # ScaffoldGS - bicycle
    {
        "method": "ScaffoldGS",
        "dataset": "mip-nerf-360",
        "scene": "bicycle",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.7461,
        "PSNR": 25.1633,
        "LPIPS": 0.2557,
    },
    # ScaffoldGS - bonsai
    {
        "method": "ScaffoldGS",
        "dataset": "mip-nerf-360",
        "scene": "bonsai",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.9488,
        "PSNR": 32.7120,
        "LPIPS": 0.1791,
    },
    # ScaffoldGS - counter
    {
        "method": "ScaffoldGS",
        "dataset": "mip-nerf-360",
        "scene": "counter",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.9186,
        "PSNR": 29.6608,
        "LPIPS": 0.1817,
    },
    # ScaffoldGS - flowers
    {
        "method": "ScaffoldGS",
        "dataset": "mip-nerf-360",
        "scene": "flowers",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.5796,
        "PSNR": 21.3169,
        "LPIPS": 0.3703,
    },
    # ScaffoldGS - garden
    {
        "method": "ScaffoldGS",
        "dataset": "mip-nerf-360",
        "scene": "garden",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.8503,
        "PSNR": 27.2767,
        "LPIPS": 0.1346,
    },
    # ScaffoldGS - kitchen
    {
        "method": "ScaffoldGS",
        "dataset": "mip-nerf-360",
        "scene": "kitchen",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.9322,
        "PSNR": 31.8245,
        "LPIPS": 0.1178,
    },
    # ScaffoldGS - room
    {
        "method": "ScaffoldGS",
        "dataset": "mip-nerf-360",
        "scene": "room",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.9310,
        "PSNR": 32.2525,
        "LPIPS": 0.1879,
    },
    # ScaffoldGS - stump
    {
        "method": "ScaffoldGS",
        "dataset": "mip-nerf-360",
        "scene": "stump",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.7644,
        "PSNR": 26.5900,
        "LPIPS": 0.2599,
    },
    # ScaffoldGS - treehill
    {
        "method": "ScaffoldGS",
        "dataset": "mip-nerf-360",
        "scene": "treehill",
        "rate_point": None,
        "rate": None,
        "SSIM": 0.6436,
        "PSNR": 23.1082,
        "LPIPS": 0.3429,
    }
])

# %%
# !for f in /home/dotamthuc/Works/Compress3DGS/Results/ContextGS/mip-nerf-360/room/*/results.json; do echo -e "$f"; cat "$f"; echo -e "\n"; done
# Out:
# /home/dotamthuc/Works/Compress3DGS/Results/ContextGS/mip-nerf-360/room/rate00/results.json
# {
#  "ours_30000": {
#   "SSIM": 0.9276200532913208,
#   "PSNR": 32.150962829589844,
#   "LPIPS": 0.19968855381011963
#  }
# }
#
# /home/dotamthuc/Works/Compress3DGS/Results/ContextGS/mip-nerf-360/room/rate01/results.json
# {
#  "ours_30000": {
#   "SSIM": 0.9262768030166626,
#   "PSNR": 32.05497741699219,
#   "LPIPS": 0.20214802026748657
#  }
# }
#
# /home/dotamthuc/Works/Compress3DGS/Results/ContextGS/mip-nerf-360/room/rate02/results.json
# {
#  "ours_30000": {
#   "SSIM": 0.9240820407867432,
#   "PSNR": 31.82016944885254,
#   "LPIPS": 0.20698313415050507
#  }
# }
#
# /home/dotamthuc/Works/Compress3DGS/Results/ContextGS/mip-nerf-360/room/rate03/results.json
# {
#  "ours_30000": {
#   "SSIM": 0.9224781394004822,
#   "PSNR": 31.81429100036621,
#   "LPIPS": 0.21072842180728912
#  }
# }

# %%
# !for f in /home/dotamthuc/Works/Compress3DGS/Results/HAC/mip-nerf-360/treehill/*/bitstreams; do du -k "$f"; done
# Out:
# 36456	/home/dotamthuc/Works/Compress3DGS/Results/HAC/mip-nerf-360/treehill/rate00/bitstreams
# 31952	/home/dotamthuc/Works/Compress3DGS/Results/HAC/mip-nerf-360/treehill/rate01/bitstreams
# 26940	/home/dotamthuc/Works/Compress3DGS/Results/HAC/mip-nerf-360/treehill/rate02/bitstreams
# 21644	/home/dotamthuc/Works/Compress3DGS/Results/HAC/mip-nerf-360/treehill/rate03/bitstreams

# %%
dataset_name = "mip-nerf-360"
baselines_result.query(f"dataset=='{dataset_name}' and rate>0").groupby(["method", "rate_point"], as_index=False)[["rate", "SSIM", "PSNR", "LPIPS"]].mean()
# Out:
#        method rate_point       rate      SSIM       PSNR     LPIPS
# 0   ContextGS          0  22.618490  0.808889  27.592533  0.232489
# 1   ContextGS          1  18.617622  0.810878  27.772867  0.231967
# 2   ContextGS          2  15.583333  0.810033  27.727889  0.234111
# 3   ContextGS          3  12.758681  0.808356  27.634567  0.238222
# 4         HAC          0  26.098958  0.810944  27.796133  0.229311
# 5         HAC          1  22.851128  0.811367  27.799500  0.229511
# 6         HAC          2  19.444444  0.809456  27.683189  0.233478
# 7         HAC          3  16.064670  0.806778  27.538600  0.238744
# 8   compactGS          0  29.122744  0.788156  26.788848  0.255454
# 9   compactGS          1  21.621500  0.766600  26.137437  0.285441
# 10  compactGS          2  19.060989  0.715055  24.702130  0.349682

# %%
baselines_result.query("scene=='kitchen' and method=='ScaffoldGS'")["PSNR"].to_numpy()
# Out:
# array([31.8245])

# %%
list_dataset = ["mip-nerf-360"] # "mip-nerf-360"

for i, dataset_name in enumerate(list_dataset):

    temp_pdf = baselines_result.query(f"dataset=='{dataset_name}' and rate>0").groupby(["method", "rate_point"], as_index=False)[["rate", "SSIM", "PSNR", "LPIPS"]].mean()
    sizes_min = int(np.min(temp_pdf["rate"].to_numpy()))
    sizes_max = int(np.max(temp_pdf["rate"].to_numpy()))
    PSNR_min = int(np.min(temp_pdf["PSNR"].to_numpy()))
    PSNR_max = int(np.max(temp_pdf["PSNR"].to_numpy()))


    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 8))

    ## BASELINE 
    temp_pdf = baselines_result.query(f"dataset=='{dataset_name}' and method=='compactGS'").groupby("rate_point", as_index=False)[["rate", "SSIM", "PSNR", "LPIPS"]].mean()
    sizes = temp_pdf["rate"].to_numpy()
    psnrs = temp_pdf["PSNR"].to_numpy()
    ax.text(sizes[0], psnrs[0], "CompactGS", color='k', ha='center', va='bottom', fontsize=13)
    ax.plot(sizes, psnrs, '--o', color='k')#, label="CompactGS")


    ## BASELINE 
    temp_pdf = baselines_result.query(f"dataset=='{dataset_name}' and method=='ContextGS'").groupby("rate_point", as_index=False)[["rate", "SSIM", "PSNR", "LPIPS"]].mean()
    sizes = temp_pdf["rate"].to_numpy()
    psnrs = temp_pdf["PSNR"].to_numpy()
    ax.text(sizes[0], psnrs[0], "ContextGS", color='k', ha='center', va='bottom', fontsize=13)
    ax.plot(sizes, psnrs, '--o', color='k')#, label="ContextGS")


    # ## BASELINE 
    temp_pdf = baselines_result.query(f"dataset=='{dataset_name}' and method=='HAC'").groupby("rate_point", as_index=False)[["rate", "SSIM", "PSNR", "LPIPS"]].mean()
    sizes = temp_pdf["rate"].to_numpy()
    psnrs = temp_pdf["PSNR"].to_numpy()
    ax.text(sizes[0], psnrs[0], "HAC", color='k', ha='center', va='bottom', fontsize=13)
    ax.plot(sizes, psnrs, '--o', color='k')#, label="HAC")


    ## Original 3DGS' 
    temp_pdf = baselines_result.query(f"dataset=='{dataset_name}' and method=='Origin3DGS'")[["rate", "SSIM", "PSNR", "LPIPS"]].mean()
    ax.axhline(temp_pdf["PSNR"], 0.0, 50.0, color='r', linestyle='-', label='Original 3DGS')
    # ax.text(sizes_max-1, psnr, 'Original 3DGS', color='red', ha='center', va='bottom', fontsize=13)

    ## SVRaster 
    temp_pdf = baselines_result.query(f"dataset=='{dataset_name}' and method=='SVRaster'")[["rate", "SSIM", "PSNR", "LPIPS"]].mean()
    ax.axhline(temp_pdf["PSNR"], 0.0, 50.0, color='b', linestyle='-', label='SVRaster')
    # ax.text(sizes_max-1, psnr, 'SVRaster', color='red', ha='center', va='bottom', fontsize=13)


    ## ScaffoldGS 
    temp_pdf = baselines_result.query(f"dataset=='{dataset_name}' and method=='ScaffoldGS'")[["rate", "SSIM", "PSNR", "LPIPS"]].mean()
    ax.axhline(temp_pdf["PSNR"], 0.0, 50.0, color='y', linestyle='-', label='ScaffoldGS')
    # ax.text(sizes_max-1, psnr, 'ScaffoldGS', color='red', ha='center', va='bottom', fontsize=13)

    ############ 
    ax.set_yticks(ticks=np.arange(PSNR_min, PSNR_max+1.5, step=0.25), labels=["{:.1f}".format(x) if i%2==0 else "" for i, x in enumerate(np.arange(PSNR_min, PSNR_max+1.5, step=0.25))], fontsize=20)
    ax.set_xticks(ticks=np.arange(sizes_min, sizes_max+1, step=1.0), labels=["{:.1f}".format(x) if i%2==0 else "" for i, x in enumerate(np.arange(sizes_min, sizes_max+1, step=1.0))], rotation=45, fontsize=20)
    ax.grid()
    ax.legend(fancybox=True, framealpha=0.5, prop={'size': 20})
    ax.set_xlabel('Megabytes (MB)', fontsize=32)
    # plt.xlim((0.3, 2.8))
    # plt.ylim((36, 46.0))
    ax.set_ylabel('Rendered RBG PSNR (dB)', fontsize=32)
    ax.set_title(f'Dataset name: {dataset_name}', fontsize=32)

    plt.show()

# %%
list_scenes = ["bicycle","bonsai","counter","flowers","garden","kitchen","room","stump", "treehill"]#"bicycle","bonsai","counter","flowers","garden","kitchen","room","stump", "treehill"


fig, ax = plt.subplots(nrows=len(list_scenes), ncols=1, figsize=(10, 8*len(list_scenes)))
fig.tight_layout()
fig.subplots_adjust(hspace=0.3)

for i, scene_name in enumerate(list_scenes):

    sizes_min = int(np.min(baselines_result.query(f"scene=='{scene_name}' and rate > 0")["rate"].to_numpy()))
    sizes_max = int(np.max(baselines_result.query(f"scene=='{scene_name}' and rate > 0")["rate"].to_numpy()))
    PSNR_min = int(np.min(baselines_result.query(f"scene=='{scene_name}' and PSNR > 0")["PSNR"].to_numpy()))
    PSNR_max = int(np.max(baselines_result.query(f"scene=='{scene_name}' and PSNR > 0")["PSNR"].to_numpy()))


    ## BASELINE 
    sizes = baselines_result.query(f"scene=='{scene_name}' and method=='compactGS'")["rate"].to_numpy()
    psnrs = baselines_result.query(f"scene=='{scene_name}' and method=='compactGS'")["PSNR"].to_numpy()
    ax[i].text(sizes[0], psnrs[0], "CompactGS", color='k', ha='center', va='bottom', fontsize=13)
    ax[i].plot(sizes, psnrs, '--o', color='k')#, label="CompactGS")


    ## BASELINE 
    sizes = baselines_result.query(f"scene=='{scene_name}' and method=='ContextGS'")["rate"].to_numpy()
    psnrs = baselines_result.query(f"scene=='{scene_name}' and method=='ContextGS'")["PSNR"].to_numpy()
    ax[i].text(sizes[0], psnrs[0], "ContextGS", color='k', ha='center', va='bottom', fontsize=13)
    ax[i].plot(sizes, psnrs, '--o', color='k')#, label="ContextGS")


    # ## BASELINE 
    sizes = baselines_result.query(f"scene=='{scene_name}' and method=='HAC'")["rate"].to_numpy()
    psnrs = baselines_result.query(f"scene=='{scene_name}' and method=='HAC'")["PSNR"].to_numpy()
    ax[i].text(sizes[0], psnrs[0], "HAC", color='k', ha='center', va='bottom', fontsize=13)
    ax[i].plot(sizes, psnrs, '--o', color='k')#, label="HAC")


    ## Original 3DGS' 
    psnr = baselines_result.query(f"scene=='{scene_name}' and method=='Origin3DGS'")["PSNR"].to_numpy()
    ax[i].axhline(psnr, 0.0, 50.0, color='r', linestyle='-', label='Original 3DGS')
    # ax.text(sizes_max-1, psnr, 'Original 3DGS', color='red', ha='center', va='bottom', fontsize=13)

    ## SVRaster 
    psnr = baselines_result.query(f"scene=='{scene_name}' and method=='SVRaster'")["PSNR"].to_numpy()
    ax[i].axhline(psnr, 0.0, 50.0, color='b', linestyle='-', label='SVRaster')
    # ax.text(sizes_max-1, psnr, 'SVRaster', color='red', ha='center', va='bottom', fontsize=13)


    ## ScaffoldGS 
    psnr = baselines_result.query(f"scene=='{scene_name}' and method=='ScaffoldGS'")["PSNR"].to_numpy()
    ax[i].axhline(psnr, 0.0, 50.0, color='y', linestyle='-', label='ScaffoldGS')
    # ax.text(sizes_max-1, psnr, 'ScaffoldGS', color='red', ha='center', va='bottom', fontsize=13)

    ############ 
    ax[i].set_yticks(ticks=np.arange(PSNR_min, PSNR_max+1.5, step=0.25), labels=["{:.1f}".format(x) if i%2==0 else "" for i, x in enumerate(np.arange(PSNR_min, PSNR_max+1.5, step=0.25))], fontsize=20)
    ax[i].set_xticks(ticks=np.arange(sizes_min, sizes_max+1, step=1.0), labels=["{:.1f}".format(x) if i%2==0 else "" for i, x in enumerate(np.arange(sizes_min, sizes_max+1, step=1.0))], rotation=45, fontsize=20)
    ax[i].grid()
    ax[i].legend(fancybox=True, framealpha=0.5, prop={'size': 20})
    ax[i].set_xlabel('Megabytes (MB)', fontsize=22)
    # plt.xlim((0.3, 2.8))
    # plt.ylim((36, 46.0))
    ax[i].set_ylabel('Rendered RBG PSNR (dB)', fontsize=22)
    ax[i].set_title(f'Scene name: {scene_name}', fontsize=32)

plt.show()
