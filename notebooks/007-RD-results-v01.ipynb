# %%
# python ./svraster/train.py \
#     --eval \
#     --source_path /home/dotamthuc-3090/Projects/ViewSynthesis/data/360_v2/kitchen \
#     --model_path /home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04 \
#     --lambda_normal_dmean 0.001 --lambda_normal_dmed 0.001 \
#     --res_downscale 8 \
#     --test_every 20 \
#     --ss 1.0 \
#     --n_iter 95000 \
#     --init_n_level 5 \
#     --adapt_every 4000 \
#     --adapt_from 4000 \
#     --prune_until 90000 \
#     --subdivide_until 90000 \
#     --subdivide_max_num 2000000 \
#     --checkpoint_iterations 999 1999 2999 3999 4999 5999 6999 7999 8999 9999 \
#                             10999 11999 12999 13999 14999 15999 16999 17999 18999 19999 \
#                             20999 21999 22999 23999 24999 25999 26999 27999 28999 29999 \
#                             30999 31999 32999 33999 34999 35999 36999 37999 38999 39999 \
#                             40999 41999 42999 43999 44999 45999 46999 47999 48999 49999 \
#                             50999 51999 52999 53999 54999 55999 56999 57999 58999 59999 \
#                             60999 61999 62999 63999 64999 65999 66999 67999 68999 69999 \
#                             70999 71999 72999 73999 74999 75999 76999 77999 78999 79999 \
#                             80999 81999 82999 83999 84999 85999 86999 87999 88999 89999 \
#                             90999 91999 92999 93999 94999 \
#     --sh_degree_init 0 \
#     --black_background \
#     --sh_degree 0


# #                             # 90999 91999 92999 93999 94999 95999 96999 97999 98999 99999 \
# #                             # 100999 101999 102999 103999 104999 105999 106999 107999 108999 109999 \
# #                             # 110999 111999 112999 113999 114999 115999 116999 117999 118999 119999 \
# #                             # 120999 121999 122999 123999 124999 125999 126999 127999 128999 129999 \

# %% [markdown]
# # 01

# %%
import os
PROJECT_ROOT = "/home/dotamthuc-3090/Projects/ViewSynthesis/"
print("PROJECT_ROOT:", PROJECT_ROOT)

import sys
lib_decompre = "/home/dotamthuc-3090/Projects/ViewSynthesis/Differentiable3DPC-Decompression-and-Rendering"
sys.path.insert(0, lib_decompre)

lib_svraster = "/home/dotamthuc-3090/Projects/ViewSynthesis/svraster"
sys.path.insert(0, lib_svraster)

import time
import itertools
import numpy as np
import torch
from matplotlib.pylab import plt

from libs.dataloader.View import View, ViewCreator
from libs.dataloader.Scene import Scene
from libs.multiscale_splats_coder.modelv00 import *
from libs.entropy_coder import rlgr


import decompress_render

from src.dataloader.data_pack import DataPack
from src.sparse_voxel_model import SparseVoxelModel
from src.config import cfg, update_argparser, update_config


torch.set_printoptions(
    precision=4,
    sci_mode=False,
    threshold=10000,    # Print the full array if it has fewer than 10000 elements
    linewidth=1000       # Number of characters per line
)
np.set_printoptions(
    precision=4,        # Number of digits of precision for floating point output
    suppress=False,      # Suppress scientific notation
    threshold=10000,    # Print the full array if it has fewer than 10000 elements
    linewidth=1000       # Number of characters per line
)
# Out:
# PROJECT_ROOT: /home/dotamthuc-3090/Projects/ViewSynthesis/

# %% [markdown]
# ## 00 Init coef for learning

# %%
# iter = 3999 nvox = 53383 psnr = 20.455171800861184
# iter = 15999 nvox = 68384 psnr = 23.861671997851698
# iter = 26999 nvox = 144737 psnr = 24.82181125978562
# iter = 35999 nvox = 250556 psnr = 25.563771738778417
# iter = 42999 nvox = 431129 psnr = 26.16217433504914
# iter = 51999 nvox = 738494 psnr = 26.630531227057624
# iter = 59999 nvox = 1245585 psnr = 26.97370018154894
# iter = 87999 nvox = 1999998 psnr = 27.346640245272

#  iter003999_model, iter015999_model, iter026999_model, iter035999_model, iter042999_model, iter051999_model, iter059999_model, iter087999_model,

torch.cuda.empty_cache()
encoder = MultiScaleSplatsEncoder(
    scene_dataset_source_path="/home/dotamthuc-3090/Projects/ViewSynthesis/data/360_v2/kitchen/",
    list_density_field_paths=[
        "/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter015999_model.pt", # 1
        "/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter026999_model.pt", # 2
        "/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter035999_model.pt", # 3
        "/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter042999_model.pt", # 4
        "/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter051999_model.pt", # 5
        "/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter059999_model.pt", # 6
        "/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter087999_model.pt", # 7
    ],
    num_sample_per_voxel=1,
    deltaQ=0.001,
    lambda_rate=1e-5,
    list_spread_b_init=[1.0, 0.2, 0.085, 0.05, 0.035, 0.025, 0.02], 
    scene_loader_opt={
        "res_downscale": 8,
        "res_width": 0,
        "encoder_view_every": 20
    },
    A_transpose_opt={
        "lr": 0.001,
        "num_scene_loop": 30,
    },
    rotation_opt={
        "max_degree": 3,
        "max_degree_grad": 3,
        "muy_phi": 0.9,
    },
    encoding_opts={
        "lr": 0.001,
        "num_loop": 25,
        "dmode": "coef_space" #coef_space / render_space
    },
    lowpass_rotation_opt = {
        "max_degree": 3,
        "max_degree_grad": 3,
        "muy_phi": 0.9,
    },
    lowpass_encoding_opts={
        "lr": 0.005,
        "num_loop": 45,
        "dmode": "coef_space" #coef_space / render_space
    }
)
# Out:
# Read dataset in COLMAP format.
# Done reading and creating views: 279 train views and 14 encoding views

# %%
output = encoder.learn_encoding()
checkpoint = {
    "trainable_parameters": encoder.trainable_params.state_dict()
}
torch.save(checkpoint, "/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/encoding_checkpoints_v01/init_learning_coef_space.pt")
# Out:
# Start Encoding Process custom_encoding_opts={'lr': 0.005, 'num_loop': 45, 'dmode': 'coef_space'}
# Encoding_attribute_field: TESTING loop = (0, 0) iter = 0 psnr=5.697608590126038 psnr_delta_field=5.101304054260254 rate=22.23702049255371 spread=[[0.9965 0.9965 0.9965]] deltaQ=[0.001]
# Encoding_attribute_field: TESTING loop = (0, 100) iter = 100 psnr=6.324201226234436 psnr_delta_field=7.544521331787109 rate=22.61489486694336 spread=[[0.7232 0.7223 0.72  ]] deltaQ=[0.0009]
# Encoding_attribute_field: TESTING loop = (0, 200) iter = 200 psnr=7.066176533699036 psnr_delta_field=5.182015895843506 rate=23.42683982849121 spread=[[0.5825 0.5774 0.5632]] deltaQ=[0.0008]
# Encoding_attribute_field: TESTING loop = (1, 21) iter = 300 psnr=7.8091466426849365 psnr_delta_field=6.119078636169434 rate=24.547056198120117 spread=[[0.5603 0.5462 0.5067]] deltaQ=[0.0007]
# Encoding_attribute_field: TESTING loop = (1, 121) iter = 400 psnr=8.539320230484009 psnr_delta_field=6.3400797843933105 rate=25.52423858642578 spread=[[0.6308 0.6046 0.5318]] deltaQ=[0.0006]
# Encoding_attribute_field: TESTING loop = (1, 221) iter = 500 psnr=9.25539493560791 psnr_delta_field=6.876727104187012 rate=26.264314651489258 spread=[[0.748  0.7095 0.6058]] deltaQ=[0.0006]
# Encoding_attribute_field: TESTING loop = (2, 42) iter = 600 psnr=9.956110119819641 psnr_delta_field=7.787892818450928 rate=26.873170852661133 spread=[[0.8769 0.8261 0.6971]] deltaQ=[0.0005]
# Encoding_attribute_field: TESTING loop = (2, 142) iter = 700 psnr=10.640134811401367 psnr_delta_field=9.12985610961914 rate=27.380754470825195 spread=[[1.0004 0.9369 0.7872]] deltaQ=[0.0005]
# Encoding_attribute_field: TESTING loop = (2, 242) iter = 800 psnr=11.306498050689697 psnr_delta_field=9.255935668945312 rate=27.819988250732422 spread=[[1.1119 1.0352 0.8684]] deltaQ=[0.0004]
# Encoding_attribute_field: TESTING loop = (3, 63) iter = 900 psnr=11.954773664474487 psnr_delta_field=9.826010704040527 rate=28.238807678222656 spread=[[1.21   1.12   0.9388]] deltaQ=[0.0004]
# Encoding_attribute_field: TESTING loop = (3, 163) iter = 1000 psnr
] deltaQ=[0.0001]
# Encoding_attribute_field: TESTING loop = (12, 152) iter = 3500 psnr=23.803799152374268 psnr_delta_field=16.293197631835938 rate=32.64032745361328 spread=[[1.9112 1.6536 1.3811]] deltaQ=[0.0001]
# Encoding_attribute_field: TESTING loop = (12, 252) iter = 3600 psnr=24.112577438354492 psnr_delta_field=16.761829376220703 rate=32.73878479003906 spread=[[1.9164 1.6565 1.3834]] deltaQ=[0.0001]
# Encoding_attribute_field: TESTING loop = (13, 73) iter = 3700 psnr=24.413902759552002 psnr_delta_field=15.222477912902832 rate=32.83552551269531 spread=[[1.9211 1.6591 1.3855]] deltaQ=[0.0001]
# Encoding_attribute_field: TESTING loop = (13, 173) iter = 3800 psnr=24.70820903778076 psnr_delta_field=13.579652786254883 rate=32.93386459350586 spread=[[1.9254 1.6615 1.3874]] deltaQ=[0.0001]
# Encoding_attribute_field: TESTING loop = (13, 273) iter = 3900 psnr=24.995994567871094 psnr_delta_field=15.240486145019531 rate=33.030460357666016 spread=[[1.9293 1.6637 1.3891]] deltaQ=[0.0001]
# Encoding_attribute_field: TESTING loop = (14, 94) iter = 4000 psnr=25.277743339538574 psnr_delta_field=15.47233772277832 rate=33.11814498901367 spread=[[1.9329 1.6657 1.3907]] deltaQ=[0.0001]
# Encoding_attribute_field: TESTING loop = (14, 194) iter = 4100 psnr=25.55349111557007 psnr_delta_field=15.271455764770508 rate=33.20974349975586 spread=[[1.9361 1.6675 1.3921]] deltaQ=[0.0001]
# Encoding_attribute_field: TESTING loop = (15, 15) iter = 4200 psnr=25.823516845703125 psnr_delta_field=14.823793411254883 rate=33.29365158081055 spread=[[1.9391 1.6691 1.3934]] deltaQ=[0.0001]
# Encoding_attribute_field: TESTING loop = (15, 115) iter = 4300 psnr=26.08814001083374 psnr_delta_field=15.31523609161377 rate=33.38440704345703 spread=[[1.9419 1.6706 1.3946]] deltaQ=[9.9858e-05]
# Encoding_attribute_field: TESTING loop = (15, 215) iter = 4400 psnr=26.347577571868896 psnr_delta_field=17.709444046020508 rate=33.472171783447266 spread=[[1.9444 1.6721 1.3957]] deltaQ=[9.7001e-05]
# Encoding_attribute_field: TESTING loop = (16, 36) iter = 4500 psnr=26.601922512054443 psnr_delta_field=15.366270065307617 rate=33.55519485473633 spread=[[1.9467 1.6733 1.3967]] deltaQ=[9.437e-05]
# Encoding_attribute_field: TESTING loop = (16, 136) iter = 4600 psnr=26.851584911346436 psnr_delta_field=16.911231994628906 rate=33.642799377441406 spread=[[1.9488 1.6746 1.3976]] deltaQ=[9.1661e-05]
# Encoding_attribute_field: TESTING loop = (16, 236) iter = 4700 psnr=27.096974849700928 psnr_delta_field=16.527843475341797 rate=33.72812271118164 spread=[[1.9507 1.6757 1.3985]] deltaQ=[8.9094e-05]
# Encoding_attribute_field: TESTING loop = (17, 57) iter = 4800 psnr=27.337956428527832 psnr_delta_field=15.970110893249512 rate=33.804115295410156 spread=[[1.9524 1.6767 1.3993]] deltaQ=[8.687e-05]
# Encoding_attribute_field: TESTING loop = (17, 157) iter = 4900 psnr=27.57481813430786 psnr_delta_field=16.44635772705078 rate=33.87232971191406 spread=[[1.9541 1.6777 1.4001]] deltaQ=[8.4923e-05]
# Encoding_attribute_field: TESTING loop = (17, 257) iter = 5000 psnr=27.807364463806152 psnr_delta_field=15.581558227539062 rate=33.9504508972168 spread=[[1.9556 1.6786 1.4008]] deltaQ=[8.2736e-05]
# Encoding_attribute_field: TESTING loop = (18, 78) iter = 5100 psnr=28.03541660308838 psnr_delta_field=16.715465545654297 rate=34.03853988647461 spread=[[1.9569 1.6794 1.4014]] deltaQ=[8.0327e-05]
# Encoding_attribute_field: TESTING loop = (18, 178) iter = 5200 psnr=28.25962543487549 psnr_delta_field=16.21820068359375 rate=34.116661071777344 spread=[[1.9582 1.6802 1.402 ]] deltaQ=[7.8251e-05]
# Encoding_attribute_field: TESTING loop = (18, 278) iter = 5300 psnr=28.47956895828247 psnr_delta_field=17.142141342163086 rate=34.19709777832031 spread=[[1.9594 1.681  1.4026]] deltaQ=[7.6166e-05]
# Encoding_attribute_field: TESTING loop = (19, 99) iter = 5400 psnr=28.695499897003174 psnr_delta_field=15.80739974975586 rate=34.283077239990234 spread=[[1.9605 1.6817 1.4032]] deltaQ=[7.3994e-05]
# Encoding_attribute_field: TESTING loop = (19, 199) iter = 5500 psnr=28.90735387802124 psnr_delta_field=15.991543769836426 rate=34.36320877075195 spread=[[1.9615 1.6823 1.4037]] deltaQ=[7.2026e-05]
# Encoding_attribute_field: TESTING loop = (20, 20) iter = 5600 psnr=29.11536455154419 psnr_delta_field=16.87660026550293 rate=34.4482421875 spread=[[1.9625 1.6829 1.4041]] deltaQ=[6.9991e-05]
# Encoding_attribute_field: TESTING loop = (20, 120) iter = 5700 psnr=29.319884777069092 psnr_delta_field=15.287524223327637 rate=34.54368591308594 spread=[[1.9634 1.6835 1.4046]] deltaQ=[6.777e-05]
# Encoding_attribute_field: TESTING loop = (20, 220) iter = 5800 psnr=29.520788192749023 psnr_delta_field=16.237159729003906 rate=34.63490676879883 spread=[[1.9642 1.6841 1.405 ]] deltaQ=[6.5713e-05]
# Encoding_attribute_field: TESTING loop = (21, 41) iter = 5900 psnr=29.7180438041687 psnr_delta_field=16.752683639526367 rate=34.719051361083984 spread=[[1.965  1.6846 1.4054]] deltaQ=[6.3871e-05]
# Encoding_attribute_field: TESTING loop = (21, 141) iter = 6000 psnr=29.91199493408203 psnr_delta_field=16.902734756469727 rate=34.79156494140625 spread=[[1.9657 1.6851 1.4058]] deltaQ=[6.2328e-05]
# Encoding_attribute_field: TESTING loop = (21, 241) iter = 6100 psnr=30.10262966156006 psnr_delta_field=17.349721908569336 rate=34.883140563964844 spread=[[1.9664 1.6856 1.4062]] deltaQ=[6.0425e-05]
# Encoding_attribute_field: TESTING loop = (22, 62) iter = 6200 psnr=30.289483070373535 psnr_delta_field=16.927120208740234 rate=34.96308135986328 spread=[[1.9671 1.686  1.4065]] deltaQ=[5.8813e-05]
# Encoding_attribute_field: TESTING loop = (22, 162) iter = 6300 psnr=30.472495555877686 psnr_delta_field=16.364280700683594 rate=35.036502838134766 spread=[[1.9677 1.6864 1.4068]] deltaQ=[5.7371e-05]
# Encoding_attribute_field: TESTING loop = (22, 262) iter = 6400 psnr=30.651848316192627 psnr_delta_field=17.852357864379883 rate=35.11709976196289 spread=[[1.9683 1.6868 1.4071]] deltaQ=[5.5827e-05]
# Encoding_attribute_field: TESTING loop = (23, 83) iter = 6500 psnr=30.827486515045166 psnr_delta_field=18.244586944580078 rate=35.210540771484375 spread=[[1.9689 1.6872 1.4074]] deltaQ=[5.4085e-05]
# Encoding_attribute_field: TESTING loop = (23, 183) iter = 6600 psnr=30.99968433380127 psnr_delta_field=17.728689193725586 rate=35.292362213134766 spread=[[1.9694 1.6876 1.4077]] deltaQ=[5.2606e-05]
# Encoding_attribute_field: TESTING loop = (24, 4) iter = 6700 psnr=31.16859197616577 psnr_delta_field=17.99235725402832 rate=35.37751770019531 spread=[[1.9699 1.6879 1.408 ]] deltaQ=[5.1108e-05]
# Encoding_attribute_field: TESTING loop = (24, 104) iter = 6800 psnr=31.334614753723145 psnr_delta_field=17.49372100830078 rate=35.45041275024414 spread=[[1.9704 1.6882 1.4082]] deltaQ=[4.9861e-05]
# Encoding_attribute_field: TESTING loop = (24, 204) iter = 6900 psnr=31.497530937194824 psnr_delta_field=16.249305725097656 rate=35.51526641845703 spread=[[1.9708 1.6886 1.4084]] deltaQ=[4.8777e-05]
# Encoding_attribute_field: TESTING loop = (25, 25) iter = 7000 psnr=31.65712833404541 psnr_delta_field=17.737747192382812 rate=35.60601043701172 spread=[[1.9713 1.6888 1.4087]] deltaQ=[4.7297e-05]
# Encoding_attribute_field: TESTING loop = (25, 125) iter = 7100 psnr=31.813552379608154 psnr_delta_field=16.519601821899414 rate=35.67875671386719 spread=[[1.9717 1.6891 1.4089]] deltaQ=[4.6143e-05]
# Encoding_attribute_field: TESTING loop = (25, 225) iter = 7200 psnr=31.96711778640747 psnr_delta_field=18.356189727783203 rate=35.72179412841797 spread=[[1.9721 1.6894 1.4091]] deltaQ=[4.5477e-05]
# Encoding_attribute_field: TESTING loop = (26, 46) iter = 7300 psnr=32.117857933044434 psnr_delta_field=16.9705867767334 rate=35.78986358642578 spread=[[1.9724 1.6896 1.4093]] deltaQ=[4.4439e-05]
# Encoding_attribute_field: TESTING loop = (26, 146) iter = 7400 psnr=32.265117168426514 psnr_delta_field=15.93079662322998 rate=35.86635208129883 spread=[[1.9728 1.6899 1.4095]] deltaQ=[4.3299e-05]
# Encoding_attribute_field: TESTING loop = (26, 246) iter = 7500 psnr=32.40933656692505 psnr_delta_field=17.015186309814453 rate=35.94380569458008 spread=[[1.9731 1.6901 1.4097]] deltaQ=[4.2174e-05]
# Encoding_attribute_field: TESTING loop = (27, 67) iter = 7600 psnr=32.55066394805908 psnr_delta_field=18.337261199951172 rate=35.99150085449219 spread=[[1.9734 1.6903 1.4098]] deltaQ=[4.1498e-05]
# Encoding_attribute_field: TESTING loop = (27, 167) iter = 7700 psnr=32.68954038619995 psnr_delta_field=17.69013023376465 rate=36.06083297729492 spread=[[1.9737 1.6906 1.41  ]] deltaQ=[4.0532e-05]
# Encoding_attribute_field: TESTING loop = (27, 267) iter = 7800 psnr=32.82578945159912 psnr_delta_field=17.072784423828125 rate=36.12986373901367 spread=[[1.974  1.6908 1.4102]] deltaQ=[3.9592e-05]
# Encoding_attribute_field: TESTING loop = (28, 88) iter = 7900 psnr=32.95930862426758 psnr_delta_field=16.64691734313965 rate=36.21223068237305 spread=[[1.9743 1.6909 1.4103]] deltaQ=[3.8497e-05]
# Encoding_attribute_field: TESTING loop = (28, 188) iter = 8000 psnr=33.09025049209595 psnr_delta_field=17.689380645751953 rate=36.289791107177734 spread=[[1.9746 1.6911 1.4105]] deltaQ=[3.7495e-05]
# Encoding_attribute_field: TESTING loop = (29, 9) iter = 8100 psnr=33.219006061553955 psnr_delta_field=17.19589614868164 rate=36.35476303100586 spread=[[1.9748 1.6913 1.4106]] deltaQ=[3.6676e-05]
# Encoding_attribute_field: TESTING loop = (29, 109) iter = 8200 psnr=33.34556579589844 psnr_delta_field=17.154396057128906 rate=36.424495697021484 spread=[[1.9751 1.6915 1.4107]] deltaQ=[3.5816e-05]
# Encoding_attribute_field: TESTING loop = (29, 209) iter = 8300 psnr=33.469905853271484 psnr_delta_field=18.821794509887695 rate=36.49766159057617 spread=[[1.9753 1.6916 1.4109]] deltaQ=[3.4935e-05]
# Encoding_attribute_field: TESTING loop = (30, 30) iter = 8400 psnr=33.59189748764038 psnr_delta_field=17.47089195251465 rate=36.573822021484375 spread=[[1.9755 1.6918 1.411 ]] deltaQ=[3.4041e-05]
# Encoding_attribute_field: TESTING loop = (30, 130) iter = 8500 psnr=33.711843490600586 psnr_delta_field=17.39238929748535 rate=36.633033752441406 spread=[[1.9757 1.6919 1.4111]] deltaQ=[3.3362e-05]
# Encoding_attribute_field: TESTING loop = (30, 230) iter = 8600 psnr=33.83018493652344 psnr_delta_field=16.865968704223633 rate=36.70515441894531 spread=[[1.9759 1.6921 1.4112]] deltaQ=[3.2553e-05]
# Encoding_attribute_field: TESTING loop = (31, 51) iter = 8700 psnr=33.94646883010864 psnr_delta_field=17.60173988342285 rate=36.755615234375 spread=[[1.9761 1.6922 1.4113]] deltaQ=[3.1999e-05]
# Encoding_attribute_field: TESTING loop = (31, 151) iter = 8800 psnr=34.06084060668945 psnr_delta_field=17.51054573059082 rate=36.80741500854492 spread=[[1.9763 1.6924 1.4114]] deltaQ=[3.144e-05]
# Encoding_attribute_field: TESTING loop = (31, 251) iter = 8900 psnr=34.173171520233154 psnr_delta_field=17.038280487060547 rate=36.88496780395508 spread=[[1.9765 1.6925 1.4116]] deltaQ=[3.062e-05]
# Encoding_attribute_field: TESTING loop = (32, 72) iter = 9000 psnr=34.28338289260864 psnr_delta_field=16.925806045532227 rate=36.93320846557617 spread=[[1.9767 1.6926 1.4117]] deltaQ=[3.0122e-05]
# Encoding_attribute_field: TESTING loop = (32, 172) iter = 9100 psnr=34.39190864562988 psnr_delta_field=17.610633850097656 rate=36.985328674316406 spread=[[1.9768 1.6927 1.4117]] deltaQ=[2.9592e-05]
# Encoding_attribute_field: TESTING loop = (32, 272) iter = 9200 psnr=34.49862241744995 psnr_delta_field=17.517961502075195 rate=37.04646301269531 spread=[[1.977  1.6928 1.4118]] deltaQ=[2.8983e-05]
# Encoding_attribute_field: TESTING loop = (33, 93) iter = 9300 psnr=34.60362672805786 psnr_delta_field=17.79589080810547 rate=37.12089920043945 spread=[[1.9771 1.693  1.4119]] deltaQ=[2.8257e-05]
# Encoding_attribute_field: TESTING loop = (33, 193) iter = 9400 psnr=34.70712184906006 psnr_delta_field=15.962041854858398 rate=37.20365524291992 spread=[[1.9773 1.6931 1.412 ]] deltaQ=[2.7471e-05]
# Encoding_attribute_field: TESTING loop = (34, 14) iter = 9500 psnr=34.809205532073975 psnr_delta_field=16.339725494384766 rate=37.27422332763672 spread=[[1.9774 1.6932 1.4121]] deltaQ=[2.6818e-05]
# Encoding_attribute_field: TESTING loop = (34, 114) iter = 9600 psnr=34.909539222717285 psnr_delta_field=17.87449073791504 rate=37.336063385009766 spread=[[1.9775 1.6933 1.4122]] deltaQ=[2.6259e-05]
# Encoding_attribute_field: TESTING loop = (34, 214) iter = 9700 psnr=35.009026527404785 psnr_delta_field=19.221952438354492 rate=37.38963317871094 spread=[[1.9777 1.6934 1.4123]] deltaQ=[2.5784e-05]
# Encoding_attribute_field: TESTING loop = (35, 35) iter = 9800 psnr=35.107131004333496 psnr_delta_field=16.475650787353516 rate=37.42427444458008 spread=[[1.9778 1.6935 1.4123]] deltaQ=[2.5482e-05]
# Encoding_attribute_field: TESTING loop = (35, 135) iter = 9900 psnr=35.20373582839966 psnr_delta_field=17.499807357788086 rate=37.47574234008789 spread=[[1.9779 1.6936 1.4124]] deltaQ=[2.5039e-05]
# Encoding_attribute_field: TESTING loop = (35, 235) iter = 10000 psnr=35.29933214187622 psnr_delta_field=17.191696166992188 rate=37.521793365478516 spread=[[1.978  1.6936 1.4125]] deltaQ=[2.4649e-05]
# Encoding_attribute_field: TESTING loop = (36, 56) iter = 10100 psnr=35.39388656616211 psnr_delta_field=17.980335235595703 rate=37.579715728759766 spread=[[1.9781 1.6937 1.4126]] deltaQ=[2.4168e-05]
# Encoding_attribute_field: TESTING loop = (36, 156) iter = 10200 psnr=35.487306118011475 psnr_delta_field=17.448287963867188 rate=37.68894958496094 spread=[[1.9782 1.6938 1.4126]] deltaQ=[2.3283e-05]
# Encoding_attribute_field: TESTING loop = (36, 256) iter = 10300 psnr=35.57957172393799 psnr_delta_field=17.79191780090332 rate=37.72602462768555 spread=[[1.9783 1.6939 1.4127]] deltaQ=[2.2991e-05]
# Encoding_attribute_field: TESTING loop = (37, 77) iter = 10400 psnr=35.670881271362305 psnr_delta_field=18.41386604309082 rate=37.73531723022461 spread=[[1.9784 1.694  1.4128]] deltaQ=[2.292e-05]
# Encoding_attribute_field: TESTING loop = (37, 177) iter = 10500 psnr=35.761311054229736 psnr_delta_field=16.88677215576172 rate=37.80642318725586 spread=[[1.9785 1.694  1.4128]] deltaQ=[2.237e-05]
# Encoding_attribute_field: TESTING loop = (37, 277) iter = 10600 psnr=35.85026264190674 psnr_delta_field=17.0966854095459 rate=37.87440872192383 spread=[[1.9786 1.6941 1.4129]] deltaQ=[2.1858e-05]
# Encoding_attribute_field: TESTING loop = (38, 98) iter = 10700 psnr=35.938193798065186 psnr_delta_field=17.68983268737793 rate=37.97947311401367 spread=[[1.9787 1.6942 1.4129]] deltaQ=[2.1088e-05]
# Encoding_attribute_field: TESTING loop = (38, 198) iter = 10800 psnr=36.02560520172119 psnr_delta_field=17.788246154785156 rate=38.083740234375 spread=[[1.9788 1.6943 1.413 ]] deltaQ=[2.035e-05]
# Encoding_attribute_field: TESTING loop = (39, 19) iter = 10900 psnr=36.11203193664551 psnr_delta_field=19.156864166259766 rate=38.14023208618164 spread=[[1.9789 1.6943 1.4131]] deltaQ=[1.9962e-05]
# Encoding_attribute_field: TESTING loop = (39, 119) iter = 11000 psnr=36.19753360748291 psnr_delta_field=17.306041717529297 rate=38.178409576416016 spread=[[1.979  1.6944 1.4131]] deltaQ=[1.9704e-05]
# Encoding_attribute_field: TESTING loop = (39, 219) iter = 11100 psnr=36.28194332122803 psnr_delta_field=16.621761322021484 rate=38.295536041259766 spread=[[1.9791 1.6945 1.4132]] deltaQ=[1.8932e-05]
# Encoding_attribute_field: TESTING loop = (40, 40) iter = 11200 psnr=36.36586666107178 psnr_delta_field=18.91935157775879 rate=38.371856689453125 spread=[[1.9791 1.6945 1.4132]] deltaQ=[1.8445e-05]
# Encoding_attribute_field: TESTING loop = (40, 140) iter = 11300 psnr=36.44906997680664 psnr_delta_field=18.494020462036133 rate=38.48143768310547 spread=[[1.9792 1.6946 1.4133]] deltaQ=[1.7768e-05]
# Encoding_attribute_field: TESTING loop = (40, 240) iter = 11400 psnr=36.53168201446533 psnr_delta_field=17.891782760620117 rate=38.534332275390625 spread=[[1.9793 1.6946 1.4133]] deltaQ=[1.745e-05]
# Encoding_attribute_field: TESTING loop = (41, 61) iter = 11500 psnr=36.613218784332275 psnr_delta_field=18.496387481689453 rate=38.55742645263672 spread=[[1.9794 1.6947 1.4134]] deltaQ=[1.7314e-05]
# Encoding_attribute_field: TESTING loop = (41, 161) iter = 11600 psnr=36.694159507751465 psnr_delta_field=18.984302520751953 rate=38.614044189453125 spread=[[1.9794 1.6948 1.4134]] deltaQ=[1.6982e-05]
# Encoding_attribute_field: TESTING loop = (41, 261) iter = 11700 psnr=36.77419185638428 psnr_delta_field=17.24698257446289 rate=38.65534210205078 spread=[[1.9795 1.6948 1.4135]] deltaQ=[1.6745e-05]
# Encoding_attribute_field: TESTING loop = (42, 82) iter = 11800 psnr=36.85325384140015 psnr_delta_field=17.778240203857422 rate=38.727684020996094 spread=[[1.9796 1.6949 1.4135]] deltaQ=[1.6337e-05]
# Encoding_attribute_field: TESTING loop = (42, 182) iter = 11900 psnr=36.93145513534546 psnr_delta_field=17.66173553466797 rate=38.751800537109375 spread=[[1.9796 1.6949 1.4135]] deltaQ=[1.6203e-05]
# Encoding_attribute_field: TESTING loop = (43, 3) iter = 12000 psnr=37.009077072143555 psnr_delta_field=16.735408782958984 rate=38.75694274902344 spread=[[1.9797 1.695  1.4136]] deltaQ=[1.6175e-05]
# Encoding_attribute_field: TESTING loop = (43, 103) iter = 12100 psnr=37.08589553833008 psnr_delta_field=17.165559768676758 rate=38.7618522644043 spread=[[1.9798 1.695  1.4136]] deltaQ=[1.6149e-05]
# Encoding_attribute_field: TESTING loop = (43, 203) iter = 12200 psnr=37.16217279434204 psnr_delta_field=17.701557159423828 rate=38.796958923339844 spread=[[1.9798 1.6951 1.4137]] deltaQ=[1.5956e-05]

# Encoding_attribute_field: TESTING loop = (5, 5) iter = 1400 psnr=43.40362071990967 psnr_delta_field=33.09602737426758 rate=61.95561599731445 spread=[[0.1049 0.1032 0.1058]] deltaQ=[2.2229e-05]
# Encoding_attribute_field: TESTING loop = (5, 105) iter = 1500 psnr=43.84175777435303 psnr_delta_field=32.98294448852539 rate=61.77398681640625 spread=[[0.1023 0.1004 0.1032]] deltaQ=[2.2829e-05]
# Encoding_attribute_field: TESTING loop = (5, 205) iter = 1600 psnr=44.262022972106934 psnr_delta_field=32.062191009521484 rate=61.55807876586914 spread=[[0.1    0.0979 0.1009]] deltaQ=[2.3592e-05]
# Encoding_attribute_field: TESTING loop = (6, 26) iter = 1700 psnr=44.66744899749756 psnr_delta_field=30.848678588867188 rate=61.378517150878906 spread=[[0.098  0.0958 0.099 ]] deltaQ=[2.4252e-05]
# Encoding_attribute_field: TESTING loop = (6, 126) iter = 1800 psnr=45.06068229675293 psnr_delta_field=31.51508140563965 rate=61.17841720581055 spread=[[0.0963 0.094  0.0975]] deltaQ=[2.5025e-05]
# Encoding_attribute_field: TESTING loop = (6, 226) iter = 1900 psnr=45.44393062591553 psnr_delta_field=31.50778579711914 rate=61.04045104980469 spread=[[0.095  0.0925 0.0962]] deltaQ=[2.5574e-05]
# Encoding_attribute_field: TESTING loop = (7, 47) iter = 2000 psnr=45.81965446472168 psnr_delta_field=30.91274070739746 rate=60.91123962402344 spread=[[0.0938 0.0913 0.0951]] deltaQ=[2.6105e-05]
# Encoding_attribute_field: TESTING loop = (7, 147) iter = 2100 psnr=46.188836097717285 psnr_delta_field=30.01131248474121 rate=60.83789825439453 spread=[[0.0929 0.0903 0.0942]] deltaQ=[2.6413e-05]
# Encoding_attribute_field: TESTING loop = (7, 247) iter = 2200 psnr=46.55245304107666 psnr_delta_field=30.832382202148438 rate=60.74074172973633 spread=[[0.0922 0.0895 0.0936]] deltaQ=[2.683e-05]
# Encoding_attribute_field: TESTING loop = (8, 68) iter = 2300 psnr=46.9116735458374 psnr_delta_field=30.739166259765625 rate=60.613990783691406 spread=[[0.0916 0.0889 0.0931]] deltaQ=[2.7387e-05]
# Encoding_attribute_field: TESTING loop = (8, 168) iter = 2400 psnr=47.26687431335449 psnr_delta_field=31.294864654541016 rate=60.54621505737305 spread=[[0.0912 0.0884 0.0927]] deltaQ=[2.7691e-05]
# Encoding_attribute_field: TESTING loop = (8, 268) iter = 2500 psnr=47.619099617004395 psnr_delta_field=29.568510055541992 rate=60.498321533203125 spread=[[0.0909 0.088  0.0924]] deltaQ=[2.791e-05]
# Encoding_attribute_field: TESTING loop = (9, 89) iter = 2600 psnr=47.968740463256836 psnr_delta_field=30.82240104675293 rate=60.45524978637695 spread=[[0.0907 0.0877 0.0922]] deltaQ=[2.811e-05]
# Encoding_attribute_field: TESTING loop = (9, 189) iter = 2700 psnr=48.31550121307373 psnr_delta_field=30.378662109375 rate=60.35200881958008 spread=[[0.0905 0.0875 0.092 ]] deltaQ=[2.8587e-05]
# Encoding_attribute_field: TESTING loop = (10, 10) iter = 2800 psnr=48.659114837646484 psnr_delta_field=31.491432189941406 rate=60.306968688964844 spread=[[0.0904 0.0874 0.0919]] deltaQ=[2.88e-05]
# Encoding_attribute_field: TESTING loop = (10, 110) iter = 2900 psnr=48.999600410461426 psnr_delta_field=31.120912551879883 rate=60.22294998168945 spread=[[0.0903 0.0873 0.0919]] deltaQ=[2.9198e-05]
# Encoding_attribute_field: TESTING loop = (10, 210) iter = 3000 psnr=49.33701038360596 psnr_delta_field=31.517906188964844 rate=60.20831298828125 spread=[[0.0903 0.0873 0.0918]] deltaQ=[2.9272e-05]
# Encoding_attribute_field: TESTING loop = (11, 31) iter = 3100 psnr=49.67100143432617 psnr_delta_field=31.175945281982422 rate=60.1563606262207 spread=[[0.0903 0.0872 0.0918]] deltaQ=[2.9523e-05]
# Encoding_attribute_field: TESTING loop = (11, 131) iter = 3200 psnr=50.00202655792236 psnr_delta_field=32.58670425415039 rate=60.20690155029297 spread=[[0.0903 0.0872 0.0918]] deltaQ=[2.9287e-05]
# Encoding_attribute_field: TESTING loop = (11, 231) iter = 3300 psnr=50.33041000366211 psnr_delta_field=29.94593048095703 rate=60.19649124145508 spread=[[0.0903 0.0872 0.0918]] deltaQ=[2.934e-05]
# Encoding_attribute_field: TESTING loop = (12, 52) iter = 3400 psnr=50.65654277801514 psnr_delta_field=29.41057014465332 rate=60.150455474853516 spread=[[0.0903 0.0872 0.0918]] deltaQ=[2.9563e-05]
# Encoding_attribute_field: TESTING loop = (12, 152) iter = 3500 psnr=50.98061561584473 psnr_delta_field=31.43871307373047 rate=60.164466857910156 spread=[[0.0903 0.0872 0.0918]] deltaQ=[2.95e-05]
# Encoding_attribute_field: TESTING loop = (12, 252) iter = 3600 psnr=51.303372383117676 psnr_delta_field=30.871292114257812 rate=60.144718170166016 spread=[[0.0903 0.0872 0.0918]] deltaQ=[2.9597e-05]
# Encoding_attribute_field: TESTING loop = (13, 73) iter = 3700 psnr=51.624789237976074 psnr_delta_field=29.413352966308594 rate=60.13394546508789 spread=[[0.0903 0.0872 0.0918]] deltaQ=[2.9652e-05]
# Encoding_attribute_field: TESTING loop = (13, 173) iter = 3800 psnr=51.945533752441406 psnr_delta_field=29.700054168701172 rate=60.151119232177734 spread=[[0.0903 0.0872 0.0918]] deltaQ=[2.9573e-05]
# Encoding_attribute_field: TESTING loop = (13, 273) iter = 3900 psnr=52.26569652557373 psnr_delta_field=30.966054916381836 rate=60.10073471069336 spread=[[0.0904 0.0872 0.0918]] deltaQ=[2.9817e-05]
# Encoding_attribute_field: TESTING loop = (14, 94) iter = 4000 psnr=52.584824562072754 psnr_delta_field=30.763431549072266 rate=60.10655975341797 spread=[[0.0904 0.0873 0.0918]] deltaQ=[2.9791e-05]
# Encoding_attribute_field: TESTING loop = (14, 194) iter = 4100 psnr=52.90294647216797 psnr_delta_field=30.665874481201172 rate=60.10398483276367 spread=[[0.0904 0.0873 0.0919]] deltaQ=[2.9806e-05]
# Encoding_attribute_field: TESTING loop = (15, 15) iter = 4200 psnr=53.21979522705078 psnr_delta_field=31.309295654296875 rate=60.06964874267578 spread=[[0.0904 0.0873 0.0919]] deltaQ=[2.9974e-05]
# Encoding_attribute_field: TESTING loop = (15, 115) iter = 4300 psnr=53.53466033935547 psnr_delta_field=31.211318969726562 rate=60.04220199584961 spread=[[0.0904 0.0873 0.0919]] deltaQ=[3.0109e-05]
# Encoding_attribute_field: TESTING loop = (15, 215) iter = 4400 psnr=53.84663105010986 psnr_delta_field=30.527645111083984 rate=60.041351318359375 spread=[[0.0904 0.0873 0.0919]] deltaQ=[3.0115e-05]
# Encoding_attribute_field: TESTING loop = (16, 36) iter = 4500 psnr=54.155449867248535 psnr_delta_field=30.492115020751953 rate=60.08208465576172 spread=[[0.0904 0.0873 0.0919]] deltaQ=[2.992e-05]
# Encoding_attribute_field: TESTING loop = (16, 136) iter = 4600 psnr=54.46063041687012 psnr_delta_field=30.977783203125 rate=60.08296203613281 spread=[[0.0904 0.0873 0.0919]] deltaQ=[2.9917e-05]
# Encoding_attribute_field: TESTING loop = (16, 236) iter = 4700 psnr=54.76172924041748 psnr_delta_field=29.965456008911133 rate=60.048805236816406 spread=[[0.0904 0.0873 0.0919]] deltaQ=[3.0084e-05]
# Encoding_attribute_field: TESTING loop = (17, 57) iter = 4800 psnr=55.058183670043945 psnr_delta_field=31.174591064453125 rate=60.0722541809082 spread=[[0.0904 0.0873 0.0919]] deltaQ=[2.9972e-05]
# Encoding_attribute_field: TESTING loop = (17, 157) iter = 4900 psnr=55.349979400634766 psnr_delta_field=30.73320198059082 rate=60.052310943603516 spread=[[0.0905 0.0873 0.0919]] deltaQ=[3.007e-05]
# Encoding_attribute_field: TESTING loop = (17, 257) iter = 5000 psnr=55.63633441925049 psnr_delta_field=30.916908264160156 rate=60.08649444580078 spread=[[0.0905 0.0873 0.0919]] deltaQ=[2.9906e-05]
# Encoding_attribute_field: TESTING loop = (18, 78) iter = 5100 psnr=55.9169864654541 psnr_delta_field=29.337894439697266 rate=60.09719467163086 spread=[[0.0905 0.0873 0.0919]] deltaQ=[2.9855e-05]
# Encoding_attribute_field: TESTING loop = (18, 178) iter = 5200 psnr=56.19115352630615 psnr_delta_field=29.08616828918457 rate=60.13532257080078 spread=[[0.0905 0.0873 0.0919]] deltaQ=[2.9673e-05]
# Encoding_attribute_field: TESTING loop = (18, 278) iter = 5300 psnr=56.458845138549805 psnr_delta_field=30.113140106201172 rate=60.185447692871094 spread=[[0.0905 0.0873 0.0919]] deltaQ=[2.9435e-05]
# Encoding_attribute_field: TESTING loop = (19, 99) iter = 5400 psnr=56.719279289245605 psnr_delta_field=28.64230728149414 rate=60.225589752197266 spread=[[0.0905 0.0873 0.0919]] deltaQ=[2.9246e-05]
# Encoding_attribute_field: TESTING loop = (19, 199) iter = 5500 psnr=56.97193145751953 psnr_delta_field=31.615697860717773 rate=60.19972610473633 spread=[[0.0905 0.0873 0.0919]] deltaQ=[2.9369e-05]
# Encoding_attribute_field: TESTING loop = (20, 20) iter = 5600 psnr=57.21601486206055 psnr_delta_field=31.10601234436035 rate=60.15270233154297 spread=[[0.0905 0.0873 0.0919]] deltaQ=[2.9594e-05]
# Encoding_attribute_field: TESTING loop = (20, 120) iter = 5700 psnr=57.45205879211426 psnr_delta_field=29.738033294677734 rate=60.128150939941406 spread=[[0.0905 0.0873 0.0919]] deltaQ=[2.9712e-05]
# Encoding_attribute_field: TESTING loop = (20, 220) iter = 5800 psnr=57.678189277648926 psnr_delta_field=31.852428436279297 rate=60.12089157104492 spread=[[0.0905 0.0873 0.0919]] deltaQ=[2.9748e-05]
# Encoding_attribute_field: TESTING loop = (21, 41) iter = 5900 psnr=57.89494037628174 psnr_delta_field=29.678686141967773 rate=60.14189910888672 spread=[[0.0905 0.0873 0.0919]] deltaQ=[2.9648e-05]
# Encoding_attribute_field: TESTING loop = (21, 141) iter = 6000 psnr=58.101768493652344 psnr_delta_field=29.155118942260742 rate=60.097412109375 spread=[[0.0905 0.0873 0.0919]] deltaQ=[2.9862e-05]
# Encoding_attribute_field: TESTING loop = (21, 241) iter = 6100 psnr=58.29793453216553 psnr_delta_field=30.509016036987305 rate=60.1248893737793 spread=[[0.0905 0.0873 0.0919]] deltaQ=[2.9731e-05]
# Encoding_attribute_field: TESTING loop = (22, 62) iter = 6200 psnr=58.48353862762451 psnr_delta_field=31.79191780090332 rate=60.153076171875 spread=[[0.0905 0.0873 0.0919]] deltaQ=[2.9596e-05]
# Encoding_attribute_field: TESTING loop = (22, 162) iter = 6300 psnr=58.65814208984375 psnr_delta_field=30.299636840820312 rate=60.199703216552734 spread=[[0.0905 0.0873 0.0919]] deltaQ=[2.9375e-05]
# Encoding_attribute_field: TESTING loop = (22, 262) iter = 6400 psnr=58.82310390472412 psnr_delta_field=31.124582290649414 rate=60.15547561645508 spread=[[0.0905 0.0873 0.0919]] deltaQ=[2.9586e-05]
# Encoding_attribute_field: TESTING loop = (23, 83) iter = 6500 psnr=58.977293968200684 psnr_delta_field=30.994091033935547 rate=60.177433013916016 spread=[[0.0905 0.0873 0.0919]] deltaQ=[2.

# Encoding_attribute_field: TESTING loop = (4, 84) iter = 1200 psnr=53.34603786468506 psnr_delta_field=31.729347229003906 rate=95.8257064819336 spread=[[0.0526 0.0533 0.0564]] deltaQ=[3.6102e-05]
# Encoding_attribute_field: TESTING loop = (4, 184) iter = 1300 psnr=53.721256256103516 psnr_delta_field=32.398685455322266 rate=95.58043670654297 spread=[[0.0516 0.0523 0.0557]] deltaQ=[3.6887e-05]
# Encoding_attribute_field: TESTING loop = (5, 5) iter = 1400 psnr=53.99627685546875 psnr_delta_field=32.275421142578125 rate=95.34474182128906 spread=[[0.0507 0.0516 0.0552]] deltaQ=[3.7669e-05]
# Encoding_attribute_field: TESTING loop = (5, 105) iter = 1500 psnr=54.200520515441895 psnr_delta_field=31.682708740234375 rate=95.08048248291016 spread=[[0.0501 0.0509 0.0548]] deltaQ=[3.8582e-05]
# Encoding_attribute_field: TESTING loop = (5, 205) iter = 1600 psnr=54.355316162109375 psnr_delta_field=31.642711639404297 rate=94.86897277832031 spread=[[0.0496 0.0505 0.0544]] deltaQ=[3.9331e-05]
# Encoding_attribute_field: TESTING loop = (6, 26) iter = 1700 psnr=54.4759464263916 psnr_delta_field=30.643827438354492 rate=94.65888977050781 spread=[[0.0492 0.0501 0.0542]] deltaQ=[4.0096e-05]
# Encoding_attribute_field: TESTING loop = (6, 126) iter = 1800 psnr=54.57189083099365 psnr_delta_field=30.18570327758789 rate=94.4620132446289 spread=[[0.0489 0.0498 0.0541]] deltaQ=[4.083e-05]
# Encoding_attribute_field: TESTING loop = (6, 226) iter = 1900 psnr=54.64883804321289 psnr_delta_field=30.999374389648438 rate=94.23963928222656 spread=[[0.0486 0.0496 0.054 ]] deltaQ=[4.168e-05]
# Encoding_attribute_field: TESTING loop = (7, 47) iter = 2000 psnr=54.71195697784424 psnr_delta_field=30.69253921508789 rate=94.10148620605469 spread=[[0.0485 0.0495 0.0539]] deltaQ=[4.2217e-05]
# Encoding_attribute_field: TESTING loop = (7, 147) iter = 2100 psnr=54.76325035095215 psnr_delta_field=30.608440399169922 rate=93.98246002197266 spread=[[0.0483 0.0494 0.0538]] deltaQ=[4.2686e-05]
# Encoding_attribute_field: TESTING loop = (7, 247) iter = 2200 psnr=54.805684089660645 psnr_delta_field=30.778676986694336 rate=93.77903747558594 spread=[[0.0483 0.0493 0.0538]] deltaQ=[4.3502e-05]
# Encoding_attribute_field: TESTING loop = (8, 68) iter = 2300 psnr=54.84172821044922 psnr_delta_field=29.269779205322266 rate=93.62035369873047 spread=[[0.0482 0.0493 0.0538]] deltaQ=[4.415e-05]
# Encoding_attribute_field: TESTING loop = (8, 168) iter = 2400 psnr=54.87142562866211 psnr_delta_field=30.565189361572266 rate=93.53541564941406 spread=[[0.0482 0.0492 0.0538]] deltaQ=[4.4502e-05]
# Encoding_attribute_field: TESTING loop = (8, 268) iter = 2500 psnr=54.89562511444092 psnr_delta_field=30.254344940185547 rate=93.4791030883789 spread=[[0.0482 0.0492 0.0538]] deltaQ=[4.4736e-05]
# Encoding_attribute_field: TESTING loop = (9, 89) iter = 2600 psnr=54.91513252258301 psnr_delta_field=30.47998809814453 rate=93.35636138916016 spread=[[0.0481 0.0492 0.0538]] deltaQ=[4.5253e-05]
# Encoding_attribute_field: TESTING loop = (9, 189) iter = 2700 psnr=54.931397438049316 psnr_delta_field=31.868907928466797 rate=93.2193832397461 spread=[[0.0481 0.0492 0.0538]] deltaQ=[4.5835e-05]
# Encoding_attribute_field: TESTING loop = (10, 10) iter = 2800 psnr=54.94478225708008 psnr_delta_field=29.801359176635742 rate=93.22418975830078 spread=[[0.0481 0.0492 0.0538]] deltaQ=[4.5816e-05]
# Encoding_attribute_field: TESTING loop = (10, 110) iter = 2900 psnr=54.95637893676758 psnr_delta_field=31.364959716796875 rate=93.27207946777344 spread=[[0.0481 0.0492 0.0538]] deltaQ=[4.5612e-05]
# Encoding_attribute_field: TESTING loop = (10, 210) iter = 3000 psnr=54.96584892272949 psnr_delta_field=30.026180267333984 rate=93.1998062133789 spread=[[0.0481 0.0492 0.0538]] deltaQ=[4.5921e-05]
spread=[[0.0084 0.0087 0.0113]] deltaQ=[0.0002]
# Encoding_attribute_field: TESTING loop = (24, 104) iter = 6800 psnr=39.87109422683716 psnr_delta_field=25.732786178588867 rate=491.10009765625 spread=[[0.0084 0.0087 0.0113]] deltaQ=[0.0002]
# Encoding_attribute_field: TESTING loop = (24, 204) iter = 6900 psnr=39.87105131149292 psnr_delta_field=25.168834686279297 rate=491.2458190917969 spread=[[0.0084 0.0087 0.0113]] deltaQ=[0.0002]

# %%
train_views = encoder.scene_dataset.get_train_views()
test_views = encoder.scene_dataset.get_encoder_views()

a_denfield= DensityField("/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter087999_model.pt")
ref_denfield= DensityField("/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter087999_model.pt")

def im_tensor2np(x):
    if x.shape[0] == 1:
        x = x.squeeze(0)
    if len(x.shape) == 3:
        x = x.moveaxis(0, -1)
    return x.clamp(0, 1).mul(255).cpu().numpy().astype(np.uint8)


list_mse = []
for view in train_views:
    tensor_img = a_denfield.apply_phi_with_F(output[1], view).detach()
    rendered_img = tensor_img.clamp(0, 1).mul(255).cpu().numpy().astype(np.uint8)

    tensor_img_target = ref_denfield.apply_phi(view).detach()
    img_target = tensor_img_target.clamp(0, 1).mul(255).cpu().numpy().astype(np.uint8)

    mse = np.square(img_target/255 - rendered_img/255).mean()
    list_mse.append(mse)

psnr = -10 * np.log10(np.mean(list_mse))
print(f"psnr = {psnr}")
# Out:
# psnr = 37.39934219708143

# %%
train_views = encoder.scene_dataset.get_train_views()
test_views = encoder.scene_dataset.get_encoder_views()

a_denfield= DensityField("/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter087999_model.pt")
ref_denfield= DensityField("/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter087999_model.pt")

def im_tensor2np(x):
    if x.shape[0] == 1:
        x = x.squeeze(0)
    if len(x.shape) == 3:
        x = x.moveaxis(0, -1)
    return x.clamp(0, 1).mul(255).cpu().numpy().astype(np.uint8)


list_mse = []
for view in train_views:
    tensor_img = a_denfield.apply_phi_with_F(output[1], view).detach()
    rendered_img = tensor_img.clamp(0, 1).mul(255).cpu().numpy().astype(np.uint8)

    tensor_img_target = ref_denfield.apply_phi(view).detach()
    img_target = tensor_img_target.clamp(0, 1).mul(255).cpu().numpy().astype(np.uint8)

    mse = np.square(img_target/255 - rendered_img/255).mean()
    list_mse.append(mse)

psnr = -10 * np.log10(np.mean(list_mse))
print(f"psnr = {psnr}")
# Out:
# psnr = 37.39934219708143

# %%
fig, ax = plt.subplots(ncols=3, nrows=len(output[0]), figsize=(21, 7*len(output[0])))
for l, coefs in enumerate(output[0]):
    for i in [0, 1, 2]:
        y = coefs[:, i].cpu().numpy()
        ind = (y > np.percentile(y, 0.01)) & (y < np.percentile(y, 99.99))

        a = np.median(y[ind])
        b = np.mean(np.abs(y[ind] - a))
        
        ax[l][i].hist(y[ind], bins=100)
        ax[l][i].set_title(f"Coefs level = {l, i} mean={a:04f} spread={b:04f} count={coefs.shape[0]}")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 10
#       7         a = np.median(y[ind])
#       8         b = np.mean(np.abs(y[ind] - a))
# ---> 10         ax[l][i].hist(y[ind], bins=100)
#      11         ax[l][i].set_title(f"Coefs level = {l, i} mean={a:04f} spread={b:04f} count={coefs.shape[0]}")
#      12 plt.show()
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %% [markdown]
# ## 001 Learning

# %%
# iter = 3999 nvox = 53383 psnr = 20.455171800861184
# iter = 15999 nvox = 68384 psnr = 23.861671997851698
# iter = 26999 nvox = 144737 psnr = 24.82181125978562
# iter = 35999 nvox = 250556 psnr = 25.563771738778417
# iter = 42999 nvox = 431129 psnr = 26.16217433504914
# iter = 51999 nvox = 738494 psnr = 26.630531227057624
# iter = 59999 nvox = 1245585 psnr = 26.97370018154894
# iter = 87999 nvox = 1999998 psnr = 27.346640245272

#  iter003999_model, iter015999_model, iter026999_model, iter035999_model, iter042999_model, iter051999_model, iter059999_model, iter087999_model,
def im_tensor2np(x):
    if x.shape[0] == 1:
        x = x.squeeze(0)
    if len(x.shape) == 3:
        x = x.moveaxis(0, -1)
    return x.clamp(0, 1).mul(255).cpu().numpy().astype(np.uint8)



torch.cuda.empty_cache()
encoder_learning = MultiScaleSplatsEncoder(
    scene_dataset_source_path="/home/dotamthuc-3090/Projects/ViewSynthesis/data/360_v2/kitchen/",
    list_density_field_paths=[
        "/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter015999_model.pt", # 1
        "/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter026999_model.pt", # 2
        "/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter035999_model.pt", # 3
        "/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter042999_model.pt", # 4
        "/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter051999_model.pt", # 5
        "/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter059999_model.pt", # 6
        "/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter087999_model.pt", # 7
    ],
    num_sample_per_voxel=1,
    deltaQ=0.001,
    lambda_rate=0.001,
    list_spread_b_init=[1.0, 0.2, 0.085, 0.05, 0.035, 0.025, 0.02], 
    scene_loader_opt={
        "res_downscale": 8,
        "res_width": 0,
        "encoder_view_every": 20
    },
    A_transpose_opt={
        "lr": 0.001,
        "num_scene_loop": 30,
    },
    rotation_opt={
        "max_degree": 3,
        "max_degree_grad": 3,
        "muy_phi": 0.9,
    },
    encoding_opts={
        "lr": 0.001,
        "num_loop": 10,
        "dmode": "coef_space" #coef_space / render_space
    },
    lowpass_rotation_opt = {
        "max_degree": 3,
        "max_degree_grad": 3,
        "muy_phi": 0.9,
    },
    lowpass_encoding_opts={
        "lr": 0.005,
        "num_loop": 10,
        "dmode": "coef_space" #coef_space / render_space
    }
)

checkpoint = torch.load("/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/encoding_checkpoints_v01/init_learning_coef_space.pt", weights_only=True)
encoder_learning.trainable_params.load_state_dict(checkpoint["trainable_parameters"])
# Out:
# Read dataset in COLMAP format.
# Done reading and creating views: 279 train views and 14 encoding views
# <All keys matched successfully>

# %%
for outer_loop in range(1, 5):
    encoder_learning.lowpass_rotation_opt["max_degree"]      = encoder_learning.lowpass_rotation_opt["max_degree"] + 1
    encoder_learning.lowpass_rotation_opt["max_degree_grad"] = encoder_learning.lowpass_rotation_opt["max_degree_grad"] + 1
    encoder_learning.rotation_opt["max_degree"]              = encoder_learning.rotation_opt["max_degree"] + 1
    encoder_learning.rotation_opt["max_degree_grad"]         = encoder_learning.rotation_opt["max_degree_grad"] + 1

    output = encoder_learning.learn_encoding()

    checkpoint = {
        "trainable_parameters": encoder_learning.trainable_params.state_dict()
    }
    torch.save(checkpoint, f"/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/encoding_checkpoints_v01/checkpoint_lambda00_te00_re{outer_loop:02d}.pt")


    print("#"*80)
    all_quantized_coefs, decoded_attribute = encoder_learning.extract_learned_encoding()
    train_views = encoder_learning.scene_dataset.get_train_views()
    a_denfield= DensityField("/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter087999_model.pt")
    ref_denfield= DensityField("/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter087999_model.pt")

    list_mse = []
    for view in train_views:
        tensor_img = a_denfield.apply_phi_with_F(decoded_attribute, view).detach()
        rendered_img = tensor_img.clamp(0, 1).mul(255).cpu().numpy().astype(np.uint8)

        tensor_img_target = ref_denfield.apply_phi(view).detach()
        img_target = tensor_img_target.clamp(0, 1).mul(255).cpu().numpy().astype(np.uint8)

        mse = np.square(img_target/255 - rendered_img/255).mean()
        list_mse.append(mse)

    psnr = -10 * np.log10(np.mean(list_mse))

    deltaQ = torch.exp2(encoder_learning.trainable_params["log2_deltaQ"]).detach().cpu().numpy()
    transformed_attributes = torch.concatenate(all_quantized_coefs).detach().cpu().numpy().astype(np.float64)

    quantization_indices = np.round(
        np.array(transformed_attributes / deltaQ)
    ).astype(np.int64)

    # entropy coder
    rate = 0
    rate += rlgr.rlgr(quantization_indices[:, 0])
    rate += rlgr.rlgr(quantization_indices[:, 1])
    rate += rlgr.rlgr(quantization_indices[:, 2])


    print(f"RESULT LEARNING psnr = {psnr} bpv = {rate/ref_denfield.num_voxels}")
# Out:
# Start Encoding Process custom_encoding_opts={'lr': 0.005, 'num_loop': 10, 'dmode': 'coef_space'}
# Encoding_attribute_field: TESTING loop = (0, 0) iter = 0 psnr
# Apply_A_transpose: loop = (1, 221) iter = 500 psnr=20.25512933731079
# Apply_A_transpose: loop = (3, 163) iter = 1000 psnr=24.43169355392456
# Apply_A_transpose: loop = (5, 105) iter = 1500 psnr=27.23316192626953
# Apply_A_transpose: loop = (7, 47) iter = 2000 psnr=29.07473087310791
# Apply_A_transpose: loop = (8, 268) iter = 2500 psnr=29.986915588378906
# Apply_A_transpose: loop = (10, 210) iter = 3000 psnr=30.537598133087158
# Apply_A_transpose: loop = (12, 152) iter = 3500 psnr=30.67411184310913
# Apply_A_transpose: loop = (14, 94) iter = 4000 psnr=30.832769870758057
# Apply_A_transpose: loop = (16, 36) iter = 4500 psnr=30.94670295715332
# Apply_A_transpose: loop = (17, 257) iter = 5000 psnr=30.924410820007324
# Apply_A_transpose: loop = (19, 199) iter = 5500 psnr=30.92566728591919
# Apply_A_transpose: loop = (21, 141) iter = 6000 psnr=30.90445041656494
# Apply_A_transpose: loop = (23, 83) iter = 6500 psnr=30.962882041931152
# Apply_A_transpose: loop = (25, 25) iter = 7000 psnr=31.022591590881348
# Apply_A_transpose: loop = (26, 246) iter = 7500 psnr=30.91400384902954
# Apply_A_transpose: loop = (28, 188) iter = 8000 psnr=30.908935070037842
# Apply_A_transpose output: psnr=30.960674285888672
# Extract encoding level=2
# Apply_A_transpose: loop = (0, 0) iter = 0 psnr=14.200903177261353
# Apply_A_transpose: loop = (1, 221) iter = 500 psnr=20.416576862335205
# Apply_A_transpose: loop = (3, 163) iter = 1000 psnr=24.923462867736816
# Apply_A_transpose: loop = (5, 105) iter = 1500 psnr=28.218393325805664
# Apply_A_transpose: loop = (7, 47) iter = 2000 psnr=30.616328716278076
# Apply_A_transpose: loop = (8, 268) iter = 2500 psnr=31.968042850494385
# Apply_A_transpose: loop = (10, 210) iter = 3000 psnr=32.871501445770264
# Apply_A_transpose: loop = (12, 152) iter = 3500 psnr=33.23367357254028
# Apply_A_transpose: loop = (14, 94) iter = 4000 psnr=33.47398519515991
# Apply_A_transpose: loop = (16, 36) iter = 4500 psnr=33.627471923828125
# Apply_A_transpose: loop = (17, 257) iter = 5000 psnr=33.64593982696533
# Apply_A_transpose: loop = (19, 199) iter = 5500 psnr=33.65309715270996
# Apply_A_transpose: loop = (21, 141) iter = 6000 psnr=33.67269992828369
# Apply_A_transpose: loop = (23, 83) iter = 6500 psnr=33.727123737335205
# Apply_A_transpose: loop = (25, 25) iter = 7000 psnr=33.78255605697632
# Apply_A_transpose: loop = (26, 246) iter = 7500 psnr=33.69862079620361
# Apply_A_transpose: loop = (28, 188) iter = 8000 psnr=33.67162227630615
# Apply_A_transpose output: psnr=33.7221884727478
# Extract encoding level=3
# Apply_A_transpose: loop = (0, 0) iter = 0 psnr=14.24553632736206
# Apply_A_transpose: loop = (1, 221) iter = 500 psnr=20.396695137023926
# Apply_A_transpose: loop = (3, 163) iter = 1000 psnr=25.035243034362793
# Apply_A_transpose: loop = (5, 105) iter = 1500 psnr=28.597474098205566
# Apply_A_transpose: loop = (7, 47) iter = 2000 psnr=31.3754940032959
# Apply_A_transpose: loop = (8, 268) iter = 2500 psnr=33.090243339538574
# Apply_A_transpose: loop = (10, 210) iter = 3000 psnr=34.33335065841675
# Apply_A_transpose: loop = (12, 152) iter = 3500 psnr=34.93748188018799
# Apply_A_transpose: loop = (14, 94) iter = 4000 psnr=35.29401779174805
# Apply_A_transpose: loop = (16, 36) iter = 4500 psnr=35.50677537918091
# Apply_A_transpose: loop = (17, 257) iter = 5000 psnr=35.561814308166504
# Apply_A_transpose: loop = (19, 199) iter = 5500 psnr=35.59315204620361
# Apply_A_transpose: loop = (21, 141) iter = 6000 psnr=35.646092891693115
# Apply_A_transpose: loop = (23, 83) iter = 6500 psnr=35.70169448852539
# Apply_A_transpose: loop = (25, 25) iter = 7000 psnr=35.74437618255615
# Apply_A_transpose: loop = (26, 246) iter = 7500 psnr=35.672240257263184
# Apply_A_transpose: loop = (28, 188) iter = 8000 psnr=35.65043926239014
# Apply_A_transpose output: psnr=35.6856632232666
# Extract encoding level=4
# Apply_A_transpose: loop = (0, 0) iter = 0 psnr=14.266924858093262
# Apply_A_transpose: loop = (1, 221) iter = 500 psnr=20.291085243225098
# Apply_A_transpose: loop = (3, 163) iter = 1000 psnr=24.95189666748047
# Apply_A_transpose: loop = (5, 105) iter = 1500 psnr=28.581295013427734
# Apply_A_transpose: loop = (7, 47) iter = 2000 psnr=31.4762282371521
# Apply_A_transpose: loop = (8, 268) iter = 2500 psnr=33.344528675079346
# Apply_A_transpose: loop = (10, 210) iter = 3000 psnr=34.76741313934326
# Apply_A_transpose: loop = (12, 152) iter = 3500 psnr=35.5137300491333
# Apply_A_transpose: loop = (14, 94) iter = 4000 psnr=35.96238374710083
# Apply_A_transpose: loop = (16, 36) iter = 4500 psnr=36.22677803039551
# Apply_A_transpose: loop = (17, 257) iter = 5000 psnr=36.31610870361328
# Apply_A_transpose: loop = (19, 199) iter = 5500 psnr=36.36957406997681
# Apply_A_transpose: loop = (21, 141) iter = 6000 psnr=36.44214868545532
# Apply_A_transpose: loop = (23, 83) iter = 6500 psnr=36.517977714538574
# Apply_A_transpose: loop = (25, 25) iter = 7000 psnr=36.5690541267395
# Apply_A_transpose: loop = (26, 246) iter = 7500 psnr=36.50786638259888
# Apply_A_transpose: loop = (28, 188) iter = 8000 psnr=36.489624977111816
# Apply_A_transpose output: psnr=36.53096675872803
# Extract encoding level=5
# Apply_A_transpose: loop = (0, 0) iter = 0 psnr=14.287571907043457
# Apply_A_transpose: loop = (1, 221) iter = 500 psnr=20.161380767822266
# Apply_A_transpose: loop = (3, 163) iter = 1000 psnr=24.83752727508545
# Apply_A_transpose: loop = (5, 105) iter = 1500 psnr=28.56861114501953
# Apply_A_transpose: loop = (7, 47) iter = 2000 psnr=31.680033206939697
# Apply_A_transpose: loop = (8, 268) iter = 2500 psnr=33.84855031967163
# Apply_A_transpose: loop = (10, 210) iter = 3000 psnr=35.626912117004395
# Apply_A_transpose: loop = (12, 152) iter = 3500 psnr=36.68567419052124
# Apply_A_transpose: loop = (14, 94) iter = 4000 psnr=37.32118844985962
# Apply_A_transpose: loop = (16, 36) iter = 4500 psnr=37.699573040008545
# Apply_A_transpose: loop = (17, 257) iter = 5000 psnr=37.87017345428467
# Apply_A_transpose: loop = (19, 199) iter = 5500 psnr=37.96736001968384
# Apply_A_transpose: loop = (21, 141) iter = 6000 psnr=38.078954219818115
# Apply_A_transpose: loop = (23, 83) iter = 6500 psnr=38.16959619522095
# Apply_A_transpose: loop = (25, 25) iter = 7000 psnr=38.23192834854126
# Apply_A_transpose: loop = (26, 246) iter = 7500 psnr=38.197221755981445
# Apply_A_transpose: loop = (28, 188) iter = 8000 psnr=38.18878889083862
# Apply_A_transpose output: psnr=38.2306694984436
# Extract encoding level=6
# Apply_A_transpose: loop = (0, 0) iter = 0 psnr=14.293421506881714
# Apply_A_transpose: loop = (1, 221) iter = 500 psnr=19.907885789871216
# Apply_A_transpose: loop = (3, 163) iter = 1000 psnr=24.40471887588501
# Apply_A_transpose: loop = (5, 105) iter = 1500 psnr=27.95182228088379
# Apply_A_transpose: loop = (7, 47) iter = 2000 psnr=30.86975336074829
# Apply_A_transpose: loop = (8, 268) iter = 2500 psnr=32.88363456726074
# Apply_A_transpose: loop = (10, 210) iter = 3000 psnr=34.52716112136841
# Apply_A_transpose: loop = (12, 152) iter = 3500 psnr=35.52234888076782
# Apply_A_transpose: loop = (14, 94) iter = 4000 psnr=36.1378812789917
# Apply_A_transpose: loop = (16, 36) iter = 4500 psnr=36.48707151412964
# Apply_A_transpose: loop = (17, 257) iter = 5000 psnr=36.64883375167847
# Apply_A_transpose: loop = (19, 199) iter = 5500 psnr=36.74949645996094
# Apply_A_transpose: loop = (21, 141) iter = 6000 psnr=36.872782707214355
# Apply_A_transpose: loop = (23, 83) iter = 6500 psnr=36.967482566833496
# Apply_A_transpose: loop = (25, 25) iter = 7000 psnr=37.0137095451355
# Apply_A_transpose: loop = (26, 246) iter = 7500 psnr=36.99616193771362
# Apply_A_transpose: loop = (28, 188) iter = 8000 psnr=36.998748779296875
# Apply_A_transpose output: psnr=37.037765979766846
# RESULT LEARNING psnr = 23.942640235083058 bpv = 1.2004202004202005

# %%
fig, ax = plt.subplots(ncols=3, nrows=len(all_quantized_coefs), figsize=(21, 7*len(all_quantized_coefs)))
for l, coefs in enumerate(all_quantized_coefs):
    for i in [0, 1, 2]:
        y = coefs[:, i].cpu().numpy()
        ind = (y > np.percentile(y, 0.01)) & (y < np.percentile(y, 99.99))

        a = np.median(y[ind])
        b = np.mean(np.abs(y[ind] - a))
        
        ax[l][i].hist(y[ind], bins=100)
        ax[l][i].set_title(f"Coefs level = {l, i} mean={a:04f} spread={b:04f} count={coefs.shape[0]}")
plt.show()

# %% [markdown]
# ## Testing

# %%
# iter = 3999 nvox = 53383 psnr = 20.455171800861184
# iter = 15999 nvox = 68384 psnr = 23.861671997851698
# iter = 26999 nvox = 144737 psnr = 24.82181125978562
# iter = 35999 nvox = 250556 psnr = 25.563771738778417
# iter = 42999 nvox = 431129 psnr = 26.16217433504914
# iter = 51999 nvox = 738494 psnr = 26.630531227057624
# iter = 59999 nvox = 1245585 psnr = 26.97370018154894
# iter = 87999 nvox = 1999998 psnr = 27.346640245272

#  iter003999_model, iter015999_model, iter026999_model, iter035999_model, iter042999_model, iter051999_model, iter059999_model, iter087999_model,


torch.cuda.empty_cache()
encoder = MultiScaleSplatsEncoder(
    scene_dataset_source_path="/home/dotamthuc-3090/Projects/ViewSynthesis/data/360_v2/kitchen/",
    list_density_field_paths=[
        "/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter015999_model.pt", # 1
        "/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter026999_model.pt", # 2
        "/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter035999_model.pt", # 3
        "/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter042999_model.pt", # 4
        "/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter051999_model.pt", # 5
        "/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter059999_model.pt", # 6
        "/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter087999_model.pt", # 7
    ],
    num_sample_per_voxel=1,
    deltaQ=0.001,
    lambda_rate=0.001,
    list_spread_b_init=[1.0, 0.2, 0.085, 0.05, 0.035, 0.025, 0.02], 
    scene_loader_opt={
        "res_downscale": 8,
        "res_width": 0,
        "encoder_view_every": 20
    },
    A_transpose_opt={
        "lr": 0.001,
        "num_scene_loop": 30,
    },
    rotation_opt={
        "max_degree": 3,
        "max_degree_grad": 3,
        "muy_phi": 0.9,
    },
    encoding_opts={
        "lr": 0.001,
        "num_loop": 10,
        "dmode": "coef_space" #coef_space / render_space
    },
    lowpass_rotation_opt = {
        "max_degree": 3,
        "max_degree_grad": 3,
        "muy_phi": 0.9,
    },
    lowpass_encoding_opts={
        "lr": 0.005,
        "num_loop": 10,
        "dmode": "coef_space" #coef_space / render_space
    }
)
# Out:
# Read dataset in COLMAP format.
# Done reading and creating views: 279 train views and 14 encoding views

# %%
checkpoint = torch.load("/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/encoding_checkpoints_v01/checkpoint_lambda00_te00_re00.pt", weights_only=True)
encoder.trainable_params.load_state_dict(checkpoint["trainable_parameters"])
# Out:
# <All keys matched successfully>

# %%
i = 3
encoder.lowpass_rotation_opt["max_degree"]      = encoder.lowpass_rotation_opt["max_degree"] + i
encoder.lowpass_rotation_opt["max_degree_grad"] = encoder.lowpass_rotation_opt["max_degree_grad"] + i
encoder.rotation_opt["max_degree"]              = encoder.rotation_opt["max_degree"] + i
encoder.rotation_opt["max_degree_grad"]         = encoder.rotation_opt["max_degree_grad"] + i

checkpoint = torch.load(f"/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/encoding_checkpoints_v01/checkpoint_lambda00_te00_re{i:02d}.pt", weights_only=True)
encoder.trainable_params.load_state_dict(checkpoint["trainable_parameters"])
# Out:
# <All keys matched successfully>

# %%
all_quantized_coefs, decoded_attribute = encoder.extract_learned_encoding()
# Out:
# Extract encoding level=1
# Apply_A_transpose: loop = (0, 0) iter = 0 psnr=14.109708070755005
# Apply_A_transpose: loop = (1, 221) iter = 500 psnr=20.291738510131836
# Apply_A_transpose: loop = (3, 163) iter = 1000 psnr=24.485065937042236
# Apply_A_transpose: loop = (5, 105) iter = 1500 psnr=27.27550506591797
# Apply_A_transpose: loop = (7, 47) iter = 2000 psnr=29.097561836242676
# Apply_A_transpose: loop = (8, 268) iter = 2500 psnr=29.996178150177002
# Apply_A_transpose: loop = (10, 210) iter = 3000 psnr=30.54149866104126
# Apply_A_transpose: loop = (12, 152) iter = 3500 psnr=30.676376819610596
# Apply_A_transpose: loop = (14, 94) iter = 4000 psnr=30.832746028900146
# Apply_A_transpose: loop = (16, 36) iter = 4500 psnr=30.947012901306152
# Apply_A_transpose: loop = (17, 257) iter = 5000 psnr=30.923080444335938
# Apply_A_transpose: loop = (19, 199) iter = 5500 psnr=30.924675464630127
# Apply_A_transpose: loop = (21, 141) iter = 6000 psnr=30.902929306030273
# Apply_A_transpose: loop = (23, 83) iter = 6500 psnr=30.96230983734131
# Apply_A_transpose: loop = (25, 25) iter = 7000 psnr=31.022427082061768
# Apply_A_transpose: loop = (26, 246) iter = 7500 psnr=30.912747383117676
# Apply_A_transpose: loop = (28, 188) iter = 8000 psnr=30.907955169677734
# Apply_A_transpose output: psnr=30.956788063049316
# Extract encoding level=2
# Apply_A_transpose: loop = (0, 0) iter = 0 psnr=14.197542667388916
# Apply_A_transpose: loop = (1, 221) iter = 500 psnr=20.453059673309326
# Apply_A_transpose: loop = (3, 163) iter = 1000 psnr=24.981045722961426
# Apply_A_transpose: loop = (5, 105) iter = 1500 psnr=28.26953649520874
# Apply_A_transpose: loop = (7, 47) iter = 2000 psnr=30.648248195648193
# Apply_A_transpose: loop = (8, 268) iter = 2500 psnr=31.984195709228516
# Apply_A_transpose: loop = (10, 210) iter = 3000 psnr=32.87894010543823
# Apply_A_transpose: loop = (12, 152) iter = 3500 psnr=33.23796510696411
# Apply_A_transpose: loop = (14, 94) iter = 4000 psnr=33.47614288330078
# Apply_A_transpose: loop = (16, 36) iter = 4500 psnr=33.62934589385986
# Apply_A_transpose: loop = (17, 257) iter = 5000 psnr=33.647422790527344
# Apply_A_transpose: loop = (19, 199) iter = 5500 psnr=33.65500450134277
# Apply_A_transpose: loop = (21, 141) iter = 6000 psnr=33.67338180541992
# Apply_A_transpose: loop = (23, 83) iter = 6500 psnr=33.7275505065918
# Apply_A_transpose: loop = (25, 25) iter = 7000 psnr=33.78180980682373
# Apply_A_transpose: loop = (26, 246) iter = 7500 psnr=33.69920253753662
# Apply_A_transpose: loop = (28, 188) iter = 8000 psnr=33.6744499206543
# Apply_A_transpose output: psnr=33.722660541534424
# Extract encoding level=3
# Apply_A_transpose: loop = (0, 0) iter = 0 psnr=14.24221396446228
# Apply_A_transpose: loop = (1, 221) iter = 500 psnr=20.432326793670654
# Apply_A_transpose: loop = (3, 163) iter = 1000 psnr=25.09324550628662
# Apply_A_transpose: loop = (5, 105) iter = 1500 psnr=28.650400638580322
# Apply_A_transpose: loop = (7, 47) iter = 2000 psnr=31.40855073928833
# Apply_A_transpose: loop = (8, 268) iter = 2500 psnr=33.10612916946411
# Apply_A_transpose: loop = (10, 210) iter = 3000 psnr=34.33898210525513
# Apply_A_transpose: loop = (12, 152) iter = 3500 psnr=34.93844509124756
# Apply_A_transpose: loop = (14, 94) iter = 4000 psnr=35.29280185699463
# Apply_A_transpose: loop = (16, 36) iter = 4500 psnr=35.5048394203186
# Apply_A_transpose: loop = (17, 257) iter = 5000 psnr=35.56093454360962
# Apply_A_transpose: loop = (19, 199) iter = 5500 psnr=35.59255361557007
# Apply_A_transpose: loop = (21, 141) iter = 6000 psnr=35.644850730895996
# Apply_A_transpose: loop = (23, 83) iter = 6500 psnr=35.70053577423096
# Apply_A_transpose: loop = (25, 25) iter = 7000 psnr=35.7418155670166
# Apply_A_transpose: loop = (26, 246) iter = 7500 psnr=35.67075252532959
# Apply_A_transpose: loop = (28, 188) iter = 8000 psnr=35.649428367614746
# Apply_A_transpose output: psnr=35.6821608543396
# Extract encoding level=4
# Apply_A_transpose: loop = (0, 0) iter = 0 psnr=14.2625892162323
# Apply_A_transpose: loop = (1, 221) iter = 500 psnr=20.323729515075684
# Apply_A_transpose: loop = (3, 163) iter = 1000 psnr=25.006263256072998
# Apply_A_transpose: loop = (5, 105) iter = 1500 psnr=28.630378246307373
# Apply_A_transpose: loop = (7, 47) iter = 2000 psnr=31.506168842315674
# Apply_A_transpose: loop = (8, 268) iter = 2500 psnr=33.35761547088623
# Apply_A_transpose: loop = (10, 210) iter = 3000 psnr=34.770073890686035
# Apply_A_transpose: loop = (12, 152) iter = 3500 psnr=35.51261901855469
# Apply_A_transpose: loop = (14, 94) iter = 4000 psnr=35.95889329910278
# Apply_A_transpose: loop = (16, 36) iter = 4500 psnr=36.22347116470337
# Apply_A_transpose: loop = (17, 257) iter = 5000 psnr=36.311635971069336
# Apply_A_transpose: loop = (19, 199) iter = 5500 psnr=36.36545419692993
# Apply_A_transpose: loop = (21, 141) iter = 6000 psnr=36.43936634063721
# Apply_A_transpose: loop = (23, 83) iter = 6500 psnr=36.51612043380737
# Apply_A_transpose: loop = (25, 25) iter = 7000 psnr=36.56716346740723
# Apply_A_transpose: loop = (26, 246) iter = 7500 psnr=36.50441884994507
# Apply_A_transpose: loop = (28, 188) iter = 8000 psnr=36.4868426322937
# Apply_A_transpose output: psnr=36.527554988861084
# Extract encoding level=5
# Apply_A_transpose: loop = (0, 0) iter = 0 psnr=14.283246994018555
# Apply_A_transpose: loop = (1, 221) iter = 500 psnr=20.19176959991455
# Apply_A_transpose: loop = (3, 163) iter = 1000 psnr=24.89100933074951
# Apply_A_transpose: loop = (5, 105) iter = 1500 psnr=28.618450164794922
# Apply_A_transpose: loop = (7, 47) iter = 2000 psnr=31.711320877075195
# Apply_A_transpose: loop = (8, 268) iter = 2500 psnr=33.86263370513916
# Apply_A_transpose: loop = (10, 210) iter = 3000 psnr=35.628390312194824
# Apply_A_transpose: loop = (12, 152) iter = 3500 psnr=36.68135404586792
# Apply_A_transpose: loop = (14, 94) iter = 4000 psnr=37.31234788894653
# Apply_A_transpose: loop = (16, 36) iter = 4500 psnr=37.691121101379395
# Apply_A_transpose: loop = (17, 257) iter = 5000 psnr=37.86247968673706
# Apply_A_transpose: loop = (19, 199) iter = 5500 psnr=37.957634925842285
# Apply_A_transpose: loop = (21, 141) iter = 6000 psnr=38.07279586791992
# Apply_A_transpose: loop = (23, 83) iter = 6500 psnr=38.16577196121216
# Apply_A_transpose: loop = (25, 25) iter = 7000 psnr=38.22737693786621
# Apply_A_transpose: loop = (26, 246) iter = 7500 psnr=38.18950414657593
# Apply_A_transpose: loop = (28, 188) iter = 8000 psnr=38.181281089782715
# Apply_A_transpose output: psnr=38.22366714477539
# Extract encoding level=6
# Apply_A_transpose: loop = (0, 0) iter = 0 psnr=14.289028644561768
# Apply_A_transpose: loop = (1, 221) iter = 500 psnr=19.93359923362732
# Apply_A_transpose: loop = (3, 163) iter = 1000 psnr=24.452810287475586
# Apply_A_transpose: loop = (5, 105) iter = 1500 psnr=27.996516227722168
# Apply_A_transpose: loop = (7, 47) iter = 2000 psnr=30.89885711669922
# Apply_A_transpose: loop = (8, 268) iter = 2500 psnr=32.898855209350586
# Apply_A_transpose: loop = (10, 210) iter = 3000 psnr=34.53249216079712
# Apply_A_transpose: loop = (12, 152) iter = 3500 psnr=35.52311420440674
# Apply_A_transpose: loop = (14, 94) iter = 4000 psnr=36.13490104675293
# Apply_A_transpose: loop = (16, 36) iter = 4500 psnr=36.4840292930603
# Apply_A_transpose: loop = (17, 257) iter = 5000 psnr=36.64635181427002
# Apply_A_transpose: loop = (19, 199) iter = 5500 psnr=36.74733638763428
# Apply_A_transpose: loop = (21, 141) iter = 6000 psnr=36.870059967041016
# Apply_A_transpose: loop = (23, 83) iter = 6500 psnr=36.964356899261475
# Apply_A_transpose: loop = (25, 25) iter = 7000 psnr=37.011024951934814
# Apply_A_transpose: loop = (26, 246) iter = 7500 psnr=36.99373960494995
# Apply_A_transpose: loop = (28, 188) iter = 8000 psnr=36.99654579162598
# Apply_A_transpose output: psnr=37.036354541778564

# %%
all_real_coefs = [encoder.trainable_params["list_learned_coefs"][i].detach().cpu().numpy() for i in range(len(encoder.trainable_params["list_learned_coefs"]))]

# %%
fig, ax = plt.subplots(ncols=3, nrows=len(all_real_coefs), figsize=(21, 7*len(all_real_coefs)))
for l, coefs in enumerate(all_real_coefs):
    for i in [0, 1, 2]:
        y = coefs[:, i]
        ind = (y > np.percentile(y, 1)) & (y < np.percentile(y, 99))

        a = np.round(np.median(y[ind]), 6)
        b = np.round(np.mean(np.abs(y[ind] - a)), 6)
        
        ax[l][i].hist(y[ind], bins=100)
        ax[l][i].set_title(f"Coefs level = {l, i} count={coefs.shape[0]} (m, b)={(a, b)}")
plt.show()

# %%
y
# Out:
# array([ 1.0590e-04,  1.9402e-05, -1.6512e-04, ..., -1.4856e-04,  1.1987e-05,  3.3927e-05], dtype=float32)

# %%
train_views = encoder.scene_dataset.get_train_views()
test_views = encoder.scene_dataset.get_encoder_views()

ref_denfield= DensityField("/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter087999_model.pt")

def im_tensor2np(x):
    if x.shape[0] == 1:
        x = x.squeeze(0)
    if len(x.shape) == 3:
        x = x.moveaxis(0, -1)
    return x.clamp(0, 1).mul(255).cpu().numpy().astype(np.uint8)


list_mse = []
for view in train_views:
    tensor_img = ref_denfield.apply_phi_with_F(decoded_attribute, view).detach()
    rendered_img = tensor_img.clamp(0, 1).mul(255).cpu().numpy().astype(np.uint8)

    tensor_img_target = ref_denfield.apply_phi(view).detach()
    img_target = tensor_img_target.clamp(0, 1).mul(255).cpu().numpy().astype(np.uint8)

    mse = np.square(img_target/255 - rendered_img/255).mean()
    list_mse.append(mse)

psnr = -10 * np.log10(np.mean(list_mse))
print(f"psnr = {psnr}")
# Out:
# psnr = 24.024078364062625

# %%
deltaQ = torch.exp2(encoder.trainable_params["log2_deltaQ"]).detach().cpu().numpy()
transformed_attributes = torch.concatenate(all_quantized_coefs).detach().cpu().numpy().astype(np.float64)

quantization_indices = np.round(
    np.array(transformed_attributes / deltaQ)
).astype(np.int64)


# entropy coder
rate = 0
rate += rlgr.rlgr(quantization_indices[:, 0])
rate += rlgr.rlgr(quantization_indices[:, 1])
rate += rlgr.rlgr(quantization_indices[:, 2])

bpv = rate/ref_denfield.num_voxels

# %%
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(12, 7))
ax.imshow(rendered_img)
ax.set_title(f"Our psnr={np.round(psnr, 4)} bpv={np.round(bpv, 4)}")
plt.show()

# %% [markdown]
# # bbb

# %%
train_views = encoder.scene_dataset.get_train_views()
test_views = encoder.scene_dataset.get_encoder_views()


a_denfield= DensityField("/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter059999_model.pt")
ref_denfield= DensityField("/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter087999_model.pt")

def im_tensor2np(x):
    if x.shape[0] == 1:
        x = x.squeeze(0)
    if len(x.shape) == 3:
        x = x.moveaxis(0, -1)
    return x.clamp(0, 1).mul(255).cpu().numpy().astype(np.uint8)


list_mse = []
for view in train_views:
    tensor_img = a_denfield.apply_phi(view).detach()
    rendered_img = tensor_img.clamp(0, 1).mul(255).cpu().numpy().astype(np.uint8)

    tensor_img_target = view.rendered_true
    img_target = im_tensor2np(tensor_img_target)

    mse = np.square(img_target/255 - rendered_img/255).mean()
    list_mse.append(mse)

psnr = -10 * np.log10(np.mean(list_mse))
print(f"psnr = {psnr}")
# Out:
# psnr = 26.97370018154894

# %%
train_views = encoder.scene_dataset.get_train_views()
test_views = encoder.scene_dataset.get_encoder_views()


a_denfield= DensityField("/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter059999_model.pt")
ref_denfield= DensityField("/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter087999_model.pt")

def im_tensor2np(x):
    if x.shape[0] == 1:
        x = x.squeeze(0)
    if len(x.shape) == 3:
        x = x.moveaxis(0, -1)
    return x.clamp(0, 1).mul(255).cpu().numpy().astype(np.uint8)


list_mse = []
for view in train_views:
    tensor_img = ref_denfield.apply_phi(view).detach()
    rendered_img = tensor_img.clamp(0, 1).mul(255).cpu().numpy().astype(np.uint8)

    tensor_img_target = view.rendered_true
    img_target = im_tensor2np(tensor_img_target)

    mse = np.square(img_target/255 - rendered_img/255).mean()
    list_mse.append(mse)

psnr = -10 * np.log10(np.mean(list_mse))
print(f"psnr = {psnr}")
# Out:
# psnr = 27.346640245272

# %%
train_views = encoder.scene_dataset.get_train_views()
test_views = encoder.scene_dataset.get_encoder_views()


a_denfield= DensityField("/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter059999_model.pt")

ref_denfield= DensityField("/home/dotamthuc-3090/Projects/ViewSynthesis/result/kitchen-v04/checkpoints/iter087999_model.pt")

def im_tensor2np(x):
    if x.shape[0] == 1:
        x = x.squeeze(0)
    if len(x.shape) == 3:
        x = x.moveaxis(0, -1)
    return x.clamp(0, 1).mul(255).cpu().numpy().astype(np.uint8)


list_mse = []
for view in train_views:
    tensor_img = a_denfield.apply_phi(view).detach()
    rendered_img = tensor_img.clamp(0, 1).mul(255).cpu().numpy().astype(np.uint8)

    tensor_img_target = ref_denfield.apply_phi(view).detach()
    img_target = tensor_img_target.clamp(0, 1).mul(255).cpu().numpy().astype(np.uint8)

    mse = np.square(img_target/255 - rendered_img/255).mean()
    list_mse.append(mse)

psnr = -10 * np.log10(np.mean(list_mse))
print(f"psnr = {psnr}")
# Out:
# psnr = 31.334566176633658

# %% [markdown]
# # END
